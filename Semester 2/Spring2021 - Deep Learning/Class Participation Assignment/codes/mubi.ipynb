# %%
import pandas as pd1
import numpy as np

# %%
# !git clone https://github.com/graphdml-uiuc-jlu/geom-gcn.git

# %%
cd /content/drive/MyDrive/ML project/codes/geom-gcn
# Out:
# /content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn

# %%
# !pip install dgl==0.3

# %%
pip install tensorboardX

# %%
# !pip install torch

# %%
import timeit
start = timeit.default_timer()

# %%
pip install AdaBound/
# Out:
# Processing ./AdaBound
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for adabound: filename=adabound-0.0.5-py3-none-any.whl size=9399 sha256=87ceafc096fb59ae902aa408d8c5efe331caf1f809ae4e648eb20b91ef61627e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9kwn6jph/wheels/1e/91/c9/a8de44992a799839b976ff22bfa4687d2d0921054cfd61c474
# Successfully built adabound
# ...
#   Attempting uninstall: adabound
#     Found existing installation: adabound 0.0.5
#     Uninstalling adabound-0.0.5:
#       Successfully uninstalled adabound-0.0.5
# ...

# %%
import adabound

# %% [markdown]
# [train_GCN.py](https://drive.google.com/drive/folders/1kDWk7PijzWE2ExI2rVj1eItspC-ghVbK)

# %%
# /content/drive/MyDrive/ML project/codes/geom-gcn/data/ind.citeseer.allx

# %%
# Your statements here
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Time:  0.018730873999999176

# %%
# import timeit
# start = timeit.default_timer()

# %%
# !bash NewTableThreeGAT_runs.txt

# %%
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 0 --dataset_split splits/citeseer_split_0.6_0.2_0.npz
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 1 --dataset_split splits/citeseer_split_0.6_0.2_0.npz
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 2 --dataset_split splits/citeseer_split_0.6_0.2_1.npz
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 3 --dataset_split splits/citeseer_split_0.6_0.2_2.npz
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 00000 | Train Loss 2.1213 | Train Acc 0.1717 | Val Loss 1.9828 | Val Acc 0.2056 | Time(s) 0.0926
# Epoch 00001 | Train Loss 1.9840 | Train Acc 0.1548 | Val Loss 1.8950 | Val Acc 0.1531 | Time(s) 0.0929
# Epoch 00002 | Train Loss 1.9154 | Train Acc 0.1604 | Val Loss 1.8344 | Val Acc 0.1934 | Time(s) 0.0903
# Epoch 00003 | Train Loss 1.8871 | Train Acc 0.1685 | Val Loss 1.7991 | Val Acc 0.1934 | Time(s) 0.0916
# Epoch 00004 | Train Loss 1.8860 | Train Acc 0.1811 | Val Loss 1.7876 | Val Acc 0.1934 | Time(s) 0.0903
# Epoch 00005 | Train Loss 1.8709 | Train Acc 0.2055 | Val Loss 1.7878 | Val Acc 0.1934 | Time(s) 0.0929
# Epoch 00006 | Train Loss 1.8507 | Train Acc 0.2030 | Val Loss 1.7943 | Val Acc 0.1934 | Time(s) 0.0919
# Epoch 00007 | Train Loss 1.8259 | Train Acc 0.2130 | Val Loss 1.8022 | Val Acc 0.1934 | Time(s) 0.0915
# Epoch 00008 | Train Loss 1.8185 | Train Acc 0.2199 | Val Loss 1.8058 | Val Acc 0.2009 | Time(s) 0.0904
# ...

# %%
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 4 --dataset_split splits/citeseer_split_0.6_0.2_0.npz
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 5 --dataset_split splits/citeseer_split_0.6_0.2_1.npz
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 6 --dataset_split splits/citeseer_split_0.6_0.2_2.npz
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 7 --dataset_split splits/citeseer_split_0.6_0.2_0.npz
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 8 --dataset_split splits/citeseer_split_0.6_0.2_1.npz
# !python train_GAT.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 9 --dataset_split splits/citeseer_split_0.6_0.2_2.npz
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 00000 | Train Loss 2.1637 | Train Acc 0.0915 | Val Loss 1.8656 | Val Acc 0.0751 | Time(s) 0.0899
# Epoch 00001 | Train Loss 1.9472 | Train Acc 0.1629 | Val Loss 1.7834 | Val Acc 0.2094 | Time(s) 0.0875
# Epoch 00002 | Train Loss 1.8630 | Train Acc 0.1767 | Val Loss 1.7573 | Val Acc 0.1972 | Time(s) 0.0851
# Epoch 00003 | Train Loss 1.8478 | Train Acc 0.1980 | Val Loss 1.7522 | Val Acc 0.1934 | Time(s) 0.0886
# Epoch 00004 | Train Loss 1.8389 | Train Acc 0.2030 | Val Loss 1.7507 | Val Acc 0.1934 | Time(s) 0.0874
# Epoch 00005 | Train Loss 1.8442 | Train Acc 0.1911 | Val Loss 1.7494 | Val Acc 0.2056 | Time(s) 0.0860
# Epoch 00006 | Train Loss 1.8255 | Train Acc 0.1924 | Val Loss 1.7500 | Val Acc 0.2056 | Time(s) 0.0854
# Epoch 00007 | Train Loss 1.8210 | Train Acc 0.1905 | Val Loss 1.7513 | Val Acc 0.2056 | Time(s) 0.0871
# Epoch 00008 | Train Loss 1.7701 | Train Acc 0.2068 | Val Loss 1.7518 | Val Acc 0.2056 | Time(s) 0.0863
# ...

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_0_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_1_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_2_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_3_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_4_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_1_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_5_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_6_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_7_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_8_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_9_results.txt') as f:
     lines = f.readlines()
     print(lines)
# Out:
# ['{"dataset": "citeseer", "num_hidden": 16, "num_heads_layer_one": 1, "num_heads_layer_two": 1, "dropout_rate": 0.5, "learning_rate": 0.05, "weight_decay_layer_one": 5e-06, "weight_decay_layer_two": 5e-06, "num_epochs_patience": 100, "num_epochs_max": 5000, "run_id": "0", "dataset_split": "splits/citeseer_split_0.6_0.2_0.npz", "learning_rate_decay_patience": 50, "learning_rate_decay_factor": 0.8, "model": "GAT_TwoLayers", "test_loss": 1.2470154762268066, "test_acc": 0.7237237691879272, "actual_epochs": 5000, "val_acc_max": 0.7521126866340637, "val_loss_min": 1.207910418510437, "total_time": 461.44850730895996}\n']
# ...

# %%
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 20 --dataset_split splits/pubmed_split_0.6_0.2_0.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 21 --dataset_split splits/pubmed_split_0.6_0.2_1.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 22 --dataset_split splits/pubmed_split_0.6_0.2_2.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 23 --dataset_split splits/pubmed_split_0.6_0.2_3.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 24 --dataset_split splits/pubmed_split_0.6_0.2_4.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 25 --dataset_split splits/pubmed_split_0.6_0.2_5.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 26 --dataset_split splits/pubmed_split_0.6_0.2_6.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 27 --dataset_split splits/pubmed_split_0.6_0.2_7.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 28 --dataset_split splits/pubmed_split_0.6_0.2_8.npz
# !python train_GAT.py --dataset pubmed --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 8 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 29 --dataset_split splits/pubmed_split_0.6_0.2_9.npz
# Out:
# /usr/local/lib/python3.7/dist-packages/adabound/adabound.py:91: UserWarning: This overload of add is deprecated:
# 	add(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   grad = grad.add(group['weight_decay'], p.data)
# Epoch 00000 | Train Loss 1.2061 | Train Acc 0.2419 | Val Loss 1.1638 | Val Acc 0.3965 | Time(s) 1.9630
# Epoch 00001 | Train Loss 1.2187 | Train Acc 0.3974 | Val Loss 1.1825 | Val Acc 0.3965 | Time(s) 1.9464
# Epoch 00002 | Train Loss 1.2391 | Train Acc 0.3919 | Val Loss 1.1038 | Val Acc 0.3965 | Time(s) 1.9231
# Epoch 00003 | Train Loss 1.1396 | Train Acc 0.3963 | Val Loss 1.0586 | Val Acc 0.3965 | Time(s) 1.9303
# Epoch 00004 | Train Loss 1.0838 | Train Acc 0.3882 | Val Loss 1.0842 | Val Acc 0.3965 | Time(s) 1.9336
# ...

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_0_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_1_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_2_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_3_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_4_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_1_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_5_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_6_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_7_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_8_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_9_results.txt') as f:
     lines = f.readlines()
     print(lines)

# %%
# #Your statements here
# stop = timeit.default_timer()
# print('Time: ', stop - start) citeseer_split_0.6_0.2_2.npz
# Out:
# Traceback (most recent call last):
#   File "train_GCN.py", line 61, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 41, in load_data
#     adj, features, labels, _, _, _ = utils.load_data(dataset_name)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils.py", line 71, in load_data
#     objects.append(pkl.load(f, encoding='latin1'))
# KeyboardInterrupt
# ^C
# /content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils.py:118: RuntimeWarning: divide by zero encountered in power
#   r_inv = np.power(rowsum, -1).flatten()

# %%
# a=!python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 0 --dataset_split splits/cora_split_0.6_0.2_0.npz
# for i in a:
#   d=i.split("|")
    


# df = pd.DataFrame(a,columns=["ID"])
# df.describe()

# %%
# print(d)
# df = pd1.DataFrame(d,columns=["ID"])
# df

# %%
df0=pd1.read_csv("BEST_ACC_GCN_0_.csv")
df0m=df0.mean()
df0m
# Out:
# 6.300469636917114258e-01    0.738989
# dtype: float64

# %%
df1=pd1.read_csv("BEST_ACC_GCN_1_.csv")
df1m =df1.mean()
df1m
# Out:
# 5.812206864356994629e-01    0.739343
# dtype: float64

# %%
df2=pd1.read_csv("BEST_ACC_GCN_2_.csv")
df2m=df2.mean()
df1m
# Out:
# 5.812206864356994629e-01    0.739343
# dtype: float64

# %%
df3=pd1.read_csv("BEST_ACC_GCN_3_.csv")
df3m=df3.mean()
df1m
# Out:
# 5.812206864356994629e-01    0.739343
# dtype: float64

# %%
df4=pd1.read_csv("BEST_ACC_GCN_4_.csv")
df4m=df4.mean()
df4m
# Out:
# 4.046948552131652832e-01    0.730135
# dtype: float64

# %%
df5=pd1.read_csv("BEST_ACC_GCN_5_.csv")
df5m=df5.mean()
df5m
# Out:
# 4.816901683807373047e-01    0.730081
# dtype: float64

# %%
df6=pd1.read_csv("BEST_ACC_GCN_6_.csv")
df6m=df6.mean()
df6m
# Out:
# 4.995305240154266357e-01    0.759027
# dtype: float64

# %%
df7=pd1.read_csv("BEST_ACC_GCN_7_.csv")
df7m=df7.mean()
df7m
# Out:
# 4.995305240154266357e-01    0.739013
# dtype: float64

# %%
df8=pd1.read_csv("BEST_ACC_GCN_8_.csv")
df8m=df8.mean()
df8m
# Out:
# 6.497652530670166016e-01    0.73443
# dtype: float64

# %%
df9=pd1.read_csv("BEST_ACC_GCN_9_.csv")
df9m=df9.mean()
df9m
# Out:
# 6.000000238418579102e-01    0.748269
# dtype: float64

# %%
MEAN = df0m+df1m+df2m+df3m+df4m+df5m+df6m+df7m+df8m+df9m
MEAN
# Out:
# 4.046948552131652832e-01   NaN
# 4.140845239162445068e-01   NaN
# 4.816901683807373047e-01   NaN
# 4.892019033432006836e-01   NaN
# 4.995305240154266357e-01   NaN
# 5.812206864356994629e-01   NaN
# 6.000000238418579102e-01   NaN
# 6.300469636917114258e-01   NaN
# 6.497652530670166016e-01   NaN
# dtype: float64

# %%
df11 = pd1.concat([df0, df1], verify_integrity=False)

# %%
df11
# Out:
#      6.300469636917114258e-01  5.812206864356994629e-01
# 0                    0.649765                       NaN
# 1                    0.633803                       NaN
# 2                    0.655399                       NaN
# 3                    0.672300                       NaN
# 4                    0.692958                       NaN
# ..                        ...                       ...
# 120                       NaN                  0.732394
# 121                       NaN                  0.733333
# 122                       NaN                  0.734272
# 123                       NaN                  0.730516
# 124                       NaN                  0.731455
#
# [254 rows x 2 columns]

# %%
df11.describe()
# Out:
#        6.300469636917114258e-01  5.812206864356994629e-01
# count                129.000000                125.000000
# mean                   0.738989                  0.739343
# std                    0.022189                  0.024982
# min                    0.633803                  0.623474
# 25%                    0.729577                  0.733333
# 50%                    0.734272                  0.738028
# 75%                    0.750235                  0.753991
# max                    0.775587                  0.775587

# %%
ls
# Out:
# BEST_ACC_GCN_0_.csv   embedding_method_combinations_all/
# BEST_ACC_GCN_11_.csv  ExperimentTwoAllGeomGCN_runs.txt
# BEST_ACC_GCN_12_.csv  ExperimentTwoAll_results.csv
# BEST_ACC_GCN_13_.csv  ExperimentTwoPairs_results.csv
# BEST_ACC_GCN_14_.csv  NewTableThreeGAT_runs.txt
# BEST_ACC_GCN_15_.csv  NewTableThreeGCN_runs.txt
# BEST_ACC_GCN_16_.csv  NewTableThreeGeomGCN_runs.txt
# BEST_ACC_GCN_17_.csv  preview.PNG
# BEST_ACC_GCN_18_.csv  __pycache__/
# BEST_ACC_GCN_19_.csv  README.md
# BEST_ACC_GCN_1_.csv   runs/
# BEST_ACC_GCN_20_.csv  splits/
# BEST_ACC_GCN_21_.csv  structural_neighborhood/
# BEST_ACC_GCN_2_.csv   train_GAT.py
# BEST_ACC_GCN_3_.csv   train_GCN.py
# BEST_ACC_GCN_4_.csv   train_GeomGCN_ExperimentTwoAll.py
# BEST_ACC_GCN_5_.csv   train_GeomGCN.py
# BEST_ACC_GCN_6_.csv   unconnected_nodes/
# BEST_ACC_GCN_7_.csv   utils_data.py
# BEST_ACC_GCN_8_.csv   utils_layers.py
# BEST_ACC_GCN_9_.csv   utils.py
# data/
