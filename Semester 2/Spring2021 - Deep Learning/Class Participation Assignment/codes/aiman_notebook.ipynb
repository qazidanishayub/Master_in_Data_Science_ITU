# %%
#!git clone https://github.com/graphdml-uiuc-jlu/geom-gcn.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/ML project/codes/geom-gcn
# Out:
# /content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn

# %%
ls
# Out:
# AdaBound/             data/
# BEST_ACC_GCN_0_.csv   embedding_method_combinations_all/
# BEST_ACC_GCN_11_.csv  ExperimentTwoAllGeomGCN_runs.txt
# BEST_ACC_GCN_12_.csv  ExperimentTwoAll_results.csv
# BEST_ACC_GCN_13_.csv  ExperimentTwoPairs_results.csv
# BEST_ACC_GCN_14_.csv  NewTableThreeGAT_runs.txt
# BEST_ACC_GCN_15_.csv  NewTableThreeGCN_runs.txt
# BEST_ACC_GCN_16_.csv  NewTableThreeGeomGCN_runs.txt
# BEST_ACC_GCN_17_.csv  preview.PNG
# BEST_ACC_GCN_18_.csv  __pycache__/
# BEST_ACC_GCN_19_.csv  README.md
# BEST_ACC_GCN_1_.csv   runs/
# BEST_ACC_GCN_20_.csv  splits/
# BEST_ACC_GCN_21_.csv  structural_neighborhood/
# BEST_ACC_GCN_2_.csv   train_GAT.py
# BEST_ACC_GCN_3_.csv   train_GCN.py
# BEST_ACC_GCN_4_.csv   train_GeomGCN_ExperimentTwoAll.py
# BEST_ACC_GCN_5_.csv   train_GeomGCN.py
# BEST_ACC_GCN_6_.csv   unconnected_nodes/
# BEST_ACC_GCN_7_.csv   utils_data.py
# BEST_ACC_GCN_8_.csv   utils_layers.py
# BEST_ACC_GCN_9_.csv   utils.py

# %%
# !pip install dgl==0.3

# %%
pip install tensorboardX

# %%
# !pip install torch

# %%
import timeit
start = timeit.default_timer()

# %% [markdown]
# ### Testset splits

# %%
from numpy import load

data = load('/content/drive/MyDrive/ML project/codes/geom-gcn/splits/cora_split_0.6_0.2_0.npz')
lst = data.files
for item in lst:
    print(type(item))
    print((data[item]))
# Out:
# <class 'str'>
# [False  True  True ... False  True  True]
# <class 'str'>
# [ True False False ... False False False]
# <class 'str'>
# [False False False ... False False False]

# %%
# import pandas as pd
# df = pd.read_csv("/content/drive/MyDrive/ML project/codes/geom-gcn/structural_neighborhood/outf_nodes_space_relation_chameleon_MDS.txt", 'r')
# df.head(10)

# %% [markdown]
# ###Embedding method combinations all

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/embedding_method_combinations_all/outf_nodes_relation_chameleonall_embedding_methods.txt') as f:
    lines = f.readlines()
    print(lines[7])
# Out:
# 986,2263	struc2vec_graph	1

# %% [markdown]
# ###structural neighbourhood

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/structural_neighborhood/outf_nodes_space_relation_chameleon_MDS.txt') as f:
    lines = f.readlines()
    print(lines[12])
# Out:
# 2171,2000	graph	1

# %% [markdown]
# GAT_train

# %% [markdown]
# ADABOUND OPTIMIZER

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_0_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_1_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_2_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_3_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_4_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_1_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_5_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_6_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_7_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_8_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_9_results.txt') as f:
     lines = f.readlines()
     print(lines)
# Out:
# ['{"dataset": "cora", "num_hidden": 8, "num_heads_layer_one": 8, "num_heads_layer_two": 1, "dropout_rate": 0.5, "learning_rate": 0.05, "weight_decay_layer_one": 5e-06, "weight_decay_layer_two": 5e-06, "num_epochs_patience": 100, "num_epochs_max": 5000, "run_id": "0", "dataset_split": "splits/cora_split_0.6_0.2_0.npz", "learning_rate_decay_patience": 50, "learning_rate_decay_factor": 0.8, "model": "GAT_TwoLayers", "test_loss": 0.6550698280334473, "test_acc": 0.8329979777336121, "actual_epochs": 5000, "val_acc_max": 0.840452253818512, "val_loss_min": 0.6352059245109558, "total_time": 2166.271127462387}\n']

# %%
import adabound

# %% [markdown]
# ###Train_GCN

# %% [markdown]
# Cora Dataset

# %%
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 0 --dataset_split splits/cora_split_0.6_0.2_0.npz
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 1 --dataset_split splits/cora_split_0.6_0.2_1.npz
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 2 --dataset_split splits/cora_split_0.6_0.2_2.npz
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 3 --dataset_split splits/cora_split_0.6_0.2_3.npz
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 5 --dataset_split splits/cora_split_0.6_0.2_5.npz
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 6 --dataset_split splits/cora_split_0.6_0.2_6.npz
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 7 --dataset_split splits/cora_split_0.6_0.2_7.npz
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 8 --dataset_split splits/cora_split_0.6_0.2_8.npz
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 9 --dataset_split splits/cora_split_0.6_0.2_9.npz

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_0_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_1_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_2_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_3_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_4_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_5_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_6_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_7_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_8_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_9_results.txt') as f:
     lines = f.readlines()
     print(lines)
# Out:
# ['{"dataset": "cora", "num_hidden": 16, "num_heads_layer_one": 1, "num_heads_layer_two": 1, "dropout_rate": 0.5, "learning_rate": 0.05, "weight_decay_layer_one": 5e-06, "weight_decay_layer_two": 5e-06, "num_epochs_patience": 100, "num_epochs_max": 5000, "run_id": "0", "dataset_split": "splits/cora_split_0.6_0.2_0.npz", "learning_rate_decay_patience": 50, "learning_rate_decay_factor": 0.8, "model": "GCN_TwoLayers", "test_loss": 0.6436781287193298, "test_acc": 0.8229376077651978, "actual_epochs": 5000, "val_acc_max": 0.8190954923629761, "val_loss_min": 0.6102519035339355, "total_time": 245.86411142349243}\n']
# ...

# %% [markdown]
# Citeseer Dataset

# %%
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 10 --dataset_split splits/citeseer_split_0.6_0.2_0.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 11 --dataset_split splits/citeseer_split_0.6_0.2_1.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 12 --dataset_split splits/citeseer_split_0.6_0.2_2.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 13 --dataset_split splits/citeseer_split_0.6_0.2_3.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 14 --dataset_split splits/citeseer_split_0.6_0.2_4.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 15 --dataset_split splits/citeseer_split_0.6_0.2_5.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 16 --dataset_split splits/citeseer_split_0.6_0.2_6.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 17 --dataset_split splits/citeseer_split_0.6_0.2_7.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 18 --dataset_split splits/citeseer_split_0.6_0.2_8.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 19 --dataset_split splits/citeseer_split_0.6_0.2_9.npz

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_10_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_11_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_12_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_13_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_14_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_15_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_16_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_17_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_18_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_19_results.txt') as f:
     lines = f.readlines()
     print(lines)
# Out:
# ['{"dataset": "citeseer", "num_hidden": 16, "num_heads_layer_one": 1, "num_heads_layer_two": 1, "dropout_rate": 0.5, "learning_rate": 0.05, "weight_decay_layer_one": 5e-06, "weight_decay_layer_two": 5e-06, "num_epochs_patience": 100, "num_epochs_max": 5000, "run_id": "10", "dataset_split": "splits/citeseer_split_0.6_0.2_0.npz", "learning_rate_decay_patience": 50, "learning_rate_decay_factor": 0.8, "model": "GCN_TwoLayers", "test_loss": 0.9374609589576721, "test_acc": 0.7342342734336853, "actual_epochs": 5000, "val_acc_max": 0.7502347826957703, "val_loss_min": 0.9051610827445984, "total_time": 168.38383436203003}\n']
# ...

# %% [markdown]
# Pubmed Dataset

# %%
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 21 --dataset_split splits/pubmed_split_0.6_0.2_1.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 22 --dataset_split splits/pubmed_split_0.6_0.2_2.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 23 --dataset_split splits/pubmed_split_0.6_0.2_3.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 24 --dataset_split splits/pubmed_split_0.6_0.2_4.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 25 --dataset_split splits/pubmed_split_0.6_0.2_5.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 26 --dataset_split splits/pubmed_split_0.6_0.2_6.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 27 --dataset_split splits/pubmed_split_0.6_0.2_7.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 28 --dataset_split splits/pubmed_split_0.6_0.2_8.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 29 --dataset_split splits/pubmed_split_0.6_0.2_9.npz

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_20_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_21_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_22_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_23_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_24_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_25_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_26_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_27_results.txt') as f:
     lines = f.readlines()
     print(lines)
# with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_28_results.txt') as f:
#      lines = f.readlines()
#      print(lines)
# with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GCN_TwoLayers_29_results.txt') as f:
#      lines = f.readlines()
#      print(lines)
# Out:
# ['{"dataset": "pubmed", "num_hidden": 64, "num_heads_layer_one": 1, "num_heads_layer_two": 1, "dropout_rate": 0.5, "learning_rate": 0.05, "weight_decay_layer_one": 5e-06, "weight_decay_layer_two": 5e-06, "num_epochs_patience": 100, "num_epochs_max": 5000, "run_id": "20", "dataset_split": "splits/pubmed_split_0.6_0.2_0.npz", "learning_rate_decay_patience": 50, "learning_rate_decay_factor": 0.8, "model": "GCN_TwoLayers", "test_loss": 0.315011590719223, "test_acc": 0.8874239325523376, "actual_epochs": 300, "val_acc_max": 0.8854199647903442, "val_loss_min": 0.3078547418117523, "total_time": 39.15963006019592}\n']
# ...

# %% [markdown]
# ###Train_GAT

# %%
import adabound

# %%
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 0 --dataset_split splits/cora_split_0.6_0.2_0.npz

# %%
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_20_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_21_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_22_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_23_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_24_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_25_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_26_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_27_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_28_results.txt') as f:
     lines = f.readlines()
     print(lines)
with open('/content/drive/MyDrive/ML project/codes/geom-gcn/runs/GAT_TwoLayers_29_results.txt') as f:
     lines = f.readlines()
     print(lines)
# Out:
# ['{"dataset": "pubmed", "num_hidden": 8, "num_heads_layer_one": 8, "num_heads_layer_two": 8, "dropout_rate": 0.5, "learning_rate": 0.05, "weight_decay_layer_one": 5e-06, "weight_decay_layer_two": 5e-06, "num_epochs_patience": 100, "num_epochs_max": 5000, "run_id": "20", "dataset_split": "splits/pubmed_split_0.6_0.2_0.npz", "learning_rate_decay_patience": 50, "learning_rate_decay_factor": 0.8, "model": "GAT_TwoLayers", "test_loss": 0.3303879499435425, "test_acc": 0.8823529481887817, "actual_epochs": 456, "val_acc_max": 0.8778129816055298, "val_loss_min": 0.32666078209877014, "total_time": 604.8968553543091}\n']
# ...

# %% [markdown]
# ###Train_GeomGcn

# %%
# !pip install Python 3.7
# !pip install PyTorch 1.7.1 Cuda 9.2
# !pip install NetworkX 2.5
# !pip install Deep Graph Library 0.3 Cuda 9.2
# !pip install Numpy 1.19.2
# !pip install Scipy 1.5.2
# !pip install Scikit-Learn 0.23.2
# !pip install Tensorflow 1.14.0
# !pip install tensorboardX
# pip install tensorboardX

# %%
from dgl import DGLGraph

# %%
# !pip install dgl-cu92  # CUDA 9.2
import dgl

# %%
print(dgl.__path__)
# Out:
# ['/usr/local/lib/python3.7/dist-packages/dgl']

# %%
# !pip install dgl-cu90  # CUDA 9.0

# !pip install dgl-cu100 # CUDA 10.0
# Out:
# ...
#      |████████████████████████████████| 25.0 MB 24 kB/s
# ...
#      |████████████████████████████████| 35.8 MB 61 kB/s
# ...
#      |████████████████████████████████| 24.6 MB 85 kB/s
# ...

# %%
import torch
torch.cuda.is_available()
torch.device('cuda:0')
torch.zeros(1).cuda()
# Out:
# tensor([0.], device='cuda:0')

# %%
device = torch.device('cuda')

# %%
# import networkx as nx
G = dgl.DGLGraph()
# G = nx.DiGraph()
G.to(torch.device(device))

# %%
cuda_G = G.to('cuda:0')  # accepts any device objects from backend framework

# %%
# !python train_GeomGCN.py --dataset chameleon --dataset_embedding poincare --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 0 --dataset_split splits/cora_split_0.6_0.2_0.npz
# Out:
# Using backend: pytorch
# /content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils.py:118: RuntimeWarning: divide by zero encountered in power
#   r_inv = np.power(rowsum, -1).flatten()
# /usr/local/lib/python3.7/dist-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)
# /usr/local/lib/python3.7/dist-packages/dgl/base.py:45: DGLWarning: DGLGraph.edge_id is deprecated. Please use DGLGraph.edge_ids.
#   return warnings.warn(message, category=category, stacklevel=1)
# Traceback (most recent call last):
#   File "train_GeomGCN.py", line 69, in <module>
#     args.dataset, args.dataset_split, None, None, 'GeomGCN', args.dataset_embedding)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 207, in load_data
# ...

# %% [markdown]
# experiment

# %%
# !python train_GeomGCN_ExperimentTwoAll.py --dataset chameleon --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 0 --dataset_split splits/cora_split_0.6_0.2_0.npz
# Out:
# Using backend: pytorch
# /content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils.py:118: RuntimeWarning: divide by zero encountered in power
#   r_inv = np.power(rowsum, -1).flatten()
# /usr/local/lib/python3.7/dist-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)
# /usr/local/lib/python3.7/dist-packages/dgl/base.py:45: DGLWarning: DGLGraph.edge_id is deprecated. Please use DGLGraph.edge_ids.
#   return warnings.warn(message, category=category, stacklevel=1)
# Traceback (most recent call last):
#   File "train_GeomGCN_ExperimentTwoAll.py", line 67, in <module>
#     args.dataset, args.dataset_split, None, None, 'ExperimentTwoAll')
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 207, in load_data
# ...

# %%
#Your statements here
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Time:  293.013457092

# %%
# import timeit
# start = timeit.default_timer()

# %%
# !bash NewTableThreeGAT_runs.txt

# %%
# #Your statements here
# stop = timeit.default_timer()
# print('Time: ', stop - start)
