# %%
# !git clone https://github.com/graphdml-uiuc-jlu/geom-gcn.git

# %%
cd /content/drive/MyDrive/ML project/codes/geom-gcn
# Out:
# /content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn

# %%
# !pip install dgl==0.3
# Out:
# Collecting dgl==0.3
#   Downloading dgl-0.3-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 4.0 MB/s
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl==0.3) (2.5.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl==0.3) (1.4.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl==0.3) (1.19.5)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.1->dgl==0.3) (4.4.2)
# Installing collected packages: dgl
# Successfully installed dgl-0.3

# %%
pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 4.1 MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.19.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.4

# %%
ls
# Out:
# AdaBound/             data/
# BEST_ACC_GCN_0_.csv   embedding_method_combinations_all/
# BEST_ACC_GCN_11_.csv  ExperimentTwoAllGeomGCN_runs.txt
# BEST_ACC_GCN_12_.csv  ExperimentTwoAll_results.csv
# BEST_ACC_GCN_13_.csv  ExperimentTwoPairs_results.csv
# BEST_ACC_GCN_14_.csv  NewTableThreeGAT_runs.txt
# BEST_ACC_GCN_15_.csv  NewTableThreeGCN_runs.txt
# BEST_ACC_GCN_16_.csv  NewTableThreeGeomGCN_runs.txt
# BEST_ACC_GCN_17_.csv  preview.PNG
# BEST_ACC_GCN_18_.csv  __pycache__/
# BEST_ACC_GCN_19_.csv  README.md
# BEST_ACC_GCN_1_.csv   runs/
# BEST_ACC_GCN_20_.csv  splits/
# BEST_ACC_GCN_21_.csv  structural_neighborhood/
# BEST_ACC_GCN_2_.csv   train_GAT.py
# BEST_ACC_GCN_3_.csv   train_GCN.py
# BEST_ACC_GCN_4_.csv   train_GeomGCN_ExperimentTwoAll.py
# BEST_ACC_GCN_5_.csv   train_GeomGCN.py
# BEST_ACC_GCN_6_.csv   unconnected_nodes/
# BEST_ACC_GCN_7_.csv   utils_data.py
# BEST_ACC_GCN_8_.csv   utils_layers.py
# BEST_ACC_GCN_9_.csv   utils.py

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)

# %% [markdown]
# [train_GCN.py](https://drive.google.com/drive/folders/1kDWk7PijzWE2ExI2rVj1eItspC-ghVbK)

# %%
# /content/drive/MyDrive/ML project/codes/geom-gcn/data/ind.citeseer.allx

# %%
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 12 --dataset_split splits/citeseer_split_0.6_0.2_2.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 13 --dataset_split splits/citeseer_split_0.6_0.2_3.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 14 --dataset_split splits/citeseer_split_0.6_0.2_4.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 15 --dataset_split splits/citeseer_split_0.6_0.2_5.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 16 --dataset_split splits/citeseer_split_0.6_0.2_6.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 17 --dataset_split splits/citeseer_split_0.6_0.2_7.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 18 --dataset_split splits/citeseer_split_0.6_0.2_8.npz
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 19 --dataset_split splits/citeseer_split_0.6_0.2_9.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 20 --dataset_split splits/pubmed_split_0.6_0.2_0.npz
# !python train_GCN.py --dataset pubmed --num_hidden 64 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 21 --dataset_split splits/pubmed_split_0.6_0.2_1.npz

# %%
# !pip install adabound
# Out:
# Requirement already satisfied: adabound in /usr/local/lib/python3.7/dist-packages (0.0.5)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from adabound) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=0.4.0->adabound) (3.7.4.3)

# %%
# !python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 80 --dataset_split splits/wisconsin_split_0.6_0.2_0.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 81 --dataset_split splits/wisconsin_split_0.6_0.2_1.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 82 --dataset_split splits/wisconsin_split_0.6_0.2_2.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 83 --dataset_split splits/wisconsin_split_0.6_0.2_3.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 84 --dataset_split splits/wisconsin_split_0.6_0.2_4.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 85 --dataset_split splits/wisconsin_split_0.6_0.2_5.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 86 --dataset_split splits/wisconsin_split_0.6_0.2_6.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 87 --dataset_split splits/wisconsin_split_0.6_0.2_7.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 88 --dataset_split splits/wisconsin_split_0.6_0.2_8.npz
# python train_GAT.py --dataset wisconsin --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 89 --dataset_split splits/wisconsin_split_0.6_0.2_9.npz
# Out:
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/wisconsin/out1_node_feature_label.txt'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 70 --dataset_split splits/texas_split_0.6_0.2_0.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 71 --dataset_split splits/texas_split_0.6_0.2_1.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 72 --dataset_split splits/texas_split_0.6_0.2_2.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 73 --dataset_split splits/texas_split_0.6_0.2_3.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 74 --dataset_split splits/texas_split_0.6_0.2_4.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 75 --dataset_split splits/texas_split_0.6_0.2_5.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 76 --dataset_split splits/texas_split_0.6_0.2_6.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 77 --dataset_split splits/texas_split_0.6_0.2_7.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 78 --dataset_split splits/texas_split_0.6_0.2_8.npz
# !python train_GAT.py --dataset texas --num_hidden 32 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-05 --weight_decay_layer_two 5e-05 --learning_rate 0.05 --dropout_rate 0.5 --run_id 79 --dataset_split splits/texas_split_0.6_0.2_9.npz
# Out:
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'
# Traceback (most recent call last):
#   File "train_GAT.py", line 62, in <module>
#     args.dataset, args.dataset_split)
#   File "/content/drive/.shortcut-targets-by-id/14H35C85iw4VocmcZsJxbnlJoZqzDUrZK/ML project/codes/geom-gcn/utils_data.py", line 66, in load_data
#     with open(graph_node_features_and_labels_file_path) as graph_node_features_and_labels_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'new_data/texas/out1_node_feature_label.txt'

# %%
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 1 --dataset_split splits/cora_split_0.6_0.2_1.npz
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 2 --dataset_split splits/cora_split_0.6_0.2_2.npz
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 3 --dataset_split splits/cora_split_0.6_0.2_3.npz
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 4 --dataset_split splits/cora_split_0.6_0.2_4.npz
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 5 --dataset_split splits/cora_split_0.6_0.2_5.npz
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 6 --dataset_split splits/cora_split_0.6_0.2_6.npz
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 7 --dataset_split splits/cora_split_0.6_0.2_7.npz
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 8 --dataset_split splits/cora_split_0.6_0.2_8.npz
# !python train_GAT.py --dataset cora --num_hidden 8 --num_heads_layer_one 8 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 9 --dataset_split splits/cora_split_0.6_0.2_9.npz

# %%
import pandas as pd
df = pd.read_csv('BEST_ACC_GCN_11_.csv')
df.describe()

# %% [markdown]
# # Time Calculation

# %%
# import timeit
# start = timeit.default_timer()

# %%
# !bash NewTableThreeGAT_runs.txt

# %%
# #Your statements here
# stop = timeit.default_timer()
# print('Time: ', stop - start)
