# %% [markdown]
# ## Homework-2
# ### Q5

# %%
# import all necessary libraries 

import numpy as np                                    # For matrices and MATLAB like functions                  
from sklearn.model_selection import train_test_split  # To split data into train and test set


# for plotting graphs
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Data Generation
#
# Input Feature Vector : $\Large x = [x_1 ,  x_2]^T$
# <br>
# Target Variable : $\Large y$
# <br>
# $$\Large  y = x_1^2 + x_2^3 + x_1x_2$$

# %%
n_samples = 1500

X = np.random.uniform(-5,5, (2, n_samples) ).astype(np.float32)

Y = (X[0, :]**2 + X[1,:]**3 + X[0,:]*X[1,:]).astype(np.float32)

# %% [markdown]
# ### Visualize Mapping from Input Feature Vector $\Large x = [x_1 ,  x_2]^T$ to target variable $\Large y$

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.axes(projection='3d')


ax.plot_trisurf(X[0],X[1],Y, cmap='twilight_shifted')
ax.view_init(30, -40)

ax.set_xlabel(r'$x_1$', fontsize=20)
ax.set_ylabel(r'$x_2$', fontsize=20)
ax.set_zlabel(r'$y$'  , fontsize=20)

plt.show()

# %%
trainX, testX, trainY, testY = train_test_split(X.T, Y, test_size=0.33, random_state=42)


trainX = trainX.reshape(trainX.shape[0], trainX.shape[1], 1 )
testX  = testX.reshape(testX.shape[0], testX.shape[1], 1 )

trainY = trainY.reshape(trainY.shape[0], 1, 1 )
testY  = testY.reshape(testY.shape[0], 1 ,1)


print("Shape of Train Data:")
print("TrainX: " , trainX.shape)
print("TrainY: " , trainY.shape)



print("\nShape of Test Data:")
print("TestX: " , testX.shape)
print("TestY: " , testY.shape)
# Out:
# Shape of Train Data:
# TrainX:  (1005, 2, 1)
# TrainY:  (1005, 1, 1)
#
# Shape of Test Data:
# TestX:  (495, 2, 1)
# TestY:  (495, 1, 1)

# %% [markdown]
# ---
#
# ## NeuralNetwork with Numpy
# ### Feed Forward and Backpropagation
#
# We will implement 3-layer neural network for regression. Following are the equations for feed forward through network. We are using sigmoid as activation function and mean-squared-error as loss.

# %% [markdown]
# $$\Large z_1  = W_1 x + b_1$$
# $$\Large h_1  = \sigma(z_1)$$
#
# <br>
# <br>
#
# $$\Large z_2  = W_2 h_1 + b_2$$
# $$\Large h_2  = \sigma(z_2)$$
#
# <br>
# <br>
#
# $$\Large \hat{y}  = W_3 h_2 + b_3$$
#
#
# <br>
# <br>
#
# $$\Large loss  = \frac{1}{N}\sum_{i=1}^{N} (y_i - \hat{y_i})^2 $$
# <center>where N is batch size</center>

# %%
class NeuralNetwork(object):        
    
    """
    We will implement neural network as a python class. 
    Object of this class will have a few attributes for example learnable parameters
    and functions such as forward(), backward_propagate() etc.
    
    """
    
    # Initialize attributes of object
    def __init__(self,  input_size = 2 , hidden_size = 3 , output_size = 1 ):        
        
        
        self.input_size  = input_size
        self.hidden_size = hidden_size 
        self.output_size = output_size
        
        
        # Learnable weights of neural network
        self.W1 = np.random.rand( hidden_size , input_size  ) # randomly initialize W1 matrix
        self.b1 = np.random.rand( hidden_size , 1           ) # randomly initialize b1 vector
        
        
        self.W2 = np.random.rand( hidden_size , hidden_size ) # randomly initialize W2 matrix
        self.b2 = np.random.rand( hidden_size , 1           ) # randomly initialize b2 vector
        
        self.W3 = np.random.rand( output_size , hidden_size ) # randomly initialize W3 matrix
        self.b3 = np.random.rand( output_size , 1           ) # randomly initialize b3 vector
        
        
        # Non-learnable parameters of neural network. These parameters are used in back-propagation
        self.z1 = np.zeros( (hidden_size , 1) ) 
        self.h1 = np.zeros( (hidden_size , 1) ) 
        
        self.z2 = np.zeros( (hidden_size , 1) ) 
        self.h2 = np.zeros( (hidden_size , 1) ) 
          
    
    
    
    # This function just prints a few properties of object created from this class    
    def __str__(self):
        
        msg = "NeuralNetwork:\n\nSize of Input Layer = " + str(self.input_size) + "\nSize of 1st Hidden Layer  = " + str(self.hidden_size)+ "\nSize of 2nd Hidden Layer  = " + str(self.hidden_size)+ "\nSize of Output Layer  = " + str(self.output_size)
                
        return  msg
        
       
    
    
    
    
        
    # Forward propagation through neural network   
    def forward(self, x):
        
        
        self.z1  = (self.W1 @ x ) + self.b1         # @ operator is used for standard matrix-multiplication 
        
        self.h1  = self.sigmoid(self.z1)            # element-wise operation on vector
        
        
        
        
        # complete forward operation
        
        
        
        
        y_hat = ....
        
        
        
        return y_hat  

    
    
    
    
    # Backward propagation through neural network
    def backward(self , y_hat , x , y , lr):

        # Assuming, MSE (mean square error) loss has been computed
        # Using chain rule, find gradients of learnable parameters of neural network
        # Adjust weights and biases using gradients and learning rate 

        # lr = learning rate
        
        
        batch_size = y_hat.shape[0]
        
        
        # Zero-out all gradients
        grad_b3 = np.zeros((batch_size, self.b3.shape[0], self.b3.shape[1] ))
        grad_W3 = np.zeros((batch_size, self.W3.shape[0], self.W3.shape[1] ))
        
        grad_b2 = np.zeros((batch_size, self.b2.shape[0], self.b2.shape[1] ))
        grad_W2 = np.zeros((batch_size, self.W2.shape[0], self.W2.shape[1] ))
        
        grad_b1 = np.zeros((batch_size, self.b1.shape[0], self.b1.shape[1] ))
        grad_W1 = np.zeros((batch_size, self.W1.shape[0], self.W1.shape[1] ))
        
        
        
        
        # Complete back propagation ...
        
        
        # Record gradients for all examples in given batch
        
            
            
        # Take average along batch dimension
           
        
        
        
        
        # Gradient Descent
        # Update weights and biases using gradients
        
        self.W3 = self.W3 - lr*grad_W3
        self.b3 = self.b3 - lr*grad_b3
        
        
        self.W2 = self.W2 - lr*grad_W2
        self.b2 = self.b2 - lr*grad_b2

        self.W1 = self.W1 - lr*grad_W1
        self.b1 = self.b1 - lr*grad_b1

        


    
    
    
    def sigmoid(self, x):
        # Activation Function
                
        sig_x = np.zeros(x.shape)
        
        # protection from overflow and underflow
        low_x = -30
        up_x  = 30
        
        sig_x[x< low_x]=0
        sig_x[x> up_x ]=1
        
        safe_x = x[(x>= low_x) & (x<= up_x)]
        sig_x[(x>= low_x) & (x<= up_x)] = np.exp(safe_x)/(1+np.exp(safe_x))
        
                
        return sig_x
            
        
        
        
    def mse_loss(self, y, y_hat):
        # Mean Square Error Loss
        
        loss  =  ((y-y_hat)**2).mean(axis=0)
        
        return loss

# %% [markdown]
# ### Creating a Randomly Initialized Neural Network

# %%
MyNeuralNet = NeuralNetwork( input_size = 2 , hidden_size = 4 , output_size = 1 )


print(MyNeuralNet)
# Out:
# NeuralNetwork:
#
# Size of Input Layer = 2
# Size of 1st Hidden Layer  = 4
# Size of 2nd Hidden Layer  = 4
# Size of Output Layer  = 1

# %% [markdown]
# ### Printing Randomly Initialized Weight Matrix and Bias Vector

# %%
print("Weight Matrix of 1st Hidden Layer:\n\nW1 = \n", MyNeuralNet.W1)
print("\n\nBias Vector of 1st Hidden Layer:\n\nb1 = \n", MyNeuralNet.b1)

print("\n\nNote:  You can easily view other learnable weight matrices and bias vectors of neural network using .dot notation.")
# Out:
# Weight Matrix of 1st Hidden Layer:
#
# W1 =
#  [[0.79417069 0.1750102 ]
#  [0.76552298 0.73500342]
#  [0.41315228 0.55478816]
#  [0.30820876 0.50690934]]
#
#
# Bias Vector of 1st Hidden Layer:
#
# b1 =
#  [[0.1396143 ]
#  [0.85884167]
#  [0.07934765]
#  [0.87848792]]
#
#
# Note:  You can easily view other learnable weight matrices and bias vectors of neural network using .dot notation.

# %%
x = trainX[:10]
y = trainY[:10]

lr = 0.1


y_hat = MyNeuralNet.forward( x )
print("W1 matrix before weight update:")
print("\nW1 = \n", MyNeuralNet.W1)
MyNeuralNet.backward( y_hat , x , y , lr)
print("\n\nW1 matrix after weight update:")
print("\nW1 = \n", MyNeuralNet.W1)
# Out:
# W1 matrix before weight update:
#
# W1 =
#  [[0.79417069 0.1750102 ]
#  [0.76552298 0.73500342]
#  [0.41315228 0.55478816]
#  [0.30820876 0.50690934]]
#
#
# W1 matrix after weight update:
#
# W1 =
#  [[0.63677784 0.70076755]
#  [0.60957249 1.02200733]
#  [0.18482619 0.94245248]
#  [0.10325858 1.00861944]]

# %% [markdown]
# ## Train Neural Network

# %%
MyNeuralNet = NeuralNetwork( input_size = 2 , hidden_size = 16 , output_size = 1 )


print(MyNeuralNet)

lr = 0.01

n_epochs = 1000

n_examples = trainX.shape[0]

batch_size = 50

n_batches = n_examples//batch_size

epoch_loss = []


print("\n\nTraining...")
for epoch in range(n_epochs):
    
    loss=0
    
    for i in range(n_batches):
        
        x = trainX[(i*batch_size):(i*batch_size+batch_size)]
        y = trainY[(i*batch_size):(i*batch_size+batch_size)]
        
        # Forward Pass
        y_hat = MyNeuralNet.forward( x )
        
        loss = loss+MyNeuralNet.mse_loss(y,y_hat)
        
        # Backpropagation
        MyNeuralNet.backward( y_hat , x , y , lr)
        
    epoch_loss.append(loss.squeeze()/n_batches)    
    print("Epoch = %3d   Loss = %3.3f"%(epoch, epoch_loss[epoch]) )
    
print("\nDone.")
# Out:
# NeuralNetwork:
#
# Size of Input Layer = 2
# Size of 1st Hidden Layer  = 16
# Size of 2nd Hidden Layer  = 16
# Size of Output Layer  = 1
#
#
# Training...
# Epoch =   0   Loss = 2305.682
# Epoch =   1   Loss = 1892.871
# Epoch =   2   Loss = 1545.349
# Epoch =   3   Loss = 1293.726
# Epoch =   4   Loss = 1234.006
# Epoch =   5   Loss = 1035.724
# Epoch =   6   Loss = 1025.915
# Epoch =   7   Loss = 909.942
# Epoch =   8   Loss = 843.454
# Epoch =   9   Loss = 768.466
# Epoch =  10   Loss = 717.718
# Epoch =  11   Loss = 694.767
# Epoch =  12   Loss = 588.831
# Epoch =  13   Loss = 614.420
# Epoch =  14   Loss = 507.392
# Epoch =  15   Loss = 448.107
# Epoch =  16   Loss = 536.632
# Epoch =  17   Loss = 416.566
# Epoch =  18   Loss = 455.497
# Epoch =  19   Loss = 383.606
# Epoch =  20   Loss = 364.920
# Epoch =  21   Loss = 320.536
# Epoch =  22   Loss = 362.005
# Epoch =  23   Loss = 376.616
# Epoch =  24   Loss = 307.350
# Epoch =  25   Loss = 300.980
# Epoch =  26   Loss = 265.599
# Epoch =  27   Loss = 263.487
# Epoch =  28   Loss = 266.309
# Epoch =  29   Loss = 285.750
# Epoch =  30   Loss = 231.213
# Epoch =  31   Loss = 265.221
# Epoch =  32   Loss = 236.017
# Epoch =  33   Loss = 235.395
# Epoch =  34   Loss = 195.945
# Epoch =  35   Loss = 222.441
# Epoch =  36   Loss = 350.699
# Epoch =  37   Loss = 262.970
# Epoch =  38   Loss = 231.811
# Epoch =  39   Loss = 253.638
# Epoch =  40   Loss = 216.895
# Epoch =  41   Loss = 226.960
# Epoch =  42   Loss = 214.116
# Epoch =  43   Loss = 220.355
# Epoch =  44   Loss = 150.455
# Epoch =  45   Loss = 198.989
# Epoch =  46   Loss = 143.697
# Epoch =  47   Loss = 221.651
# Epoch =  48   Loss = 160.579
# Epoch =  49   Loss = 152.091
# Epoch =  50   Loss = 148.184
# Epoch =  51   Loss = 159.839
# Epoch =  52   Loss = 158.750
# Epoch =  53   Loss = 115.407
# Epoch =  54   Loss = 121.490
# Epoch =  55   Loss = 170.917
# Epoch =  56   Loss = 99.647
# Epoch =  57   Loss = 151.563
# Epoch =  58   Loss = 105.883
# Epoch =  59   Loss = 118.108
# Epoch =  60   Loss = 106.411
# Epoch =  61   Loss = 95.667
# Epoch =  62   Loss = 121.581
# Epoch =  63   Loss = 85.407
# Epoch =  64   Loss = 84.461
# Epoch =  65   Loss = 74.048
# Epoch =  66   Loss = 71.259
# Epoch =  67   Loss = 83.365
# Epoch =  68   Loss = 122.525
# Epoch =  69   Loss = 79.282
# Epoch =  70   Loss = 69.749
# Epoch =  71   Loss = 71.613
# Epoch =  72   Loss = 62.384
# Epoch =  73   Loss = 78.062
# Epoch =  74   Loss = 108.821
# Epoch =  75   Loss = 99.152
# Epoch =  76   Loss = 110.840
# Epoch =  77   Loss = 76.564
# Epoch =  78   Loss = 58.823
# Epoch =  79   Loss = 53.467
# Epoch =  80   Loss = 53.314
# Epoch =  81   Loss = 62.626
# Epoch =  82   Loss = 88.566
# Epoch =  83   Loss = 61.995
# Epoch =  84   Loss = 50.163
# Epoch =  85   Loss = 60.246
# Epoch =  86   Loss = 80.021
# Epoch =  87   Loss = 74.909
# Epoch =  88   Loss = 63.800
# Epoch =  89   Loss = 67.039
# Epoch =  90   Loss = 72.143
# Epoch =  91   Loss = 59.515
# Epoch =  92   Loss = 51.331
# Epoch =  93   Loss = 57.310
# Epoch =  94   Loss = 64.063
# Epoch =  95   Loss = 73.822
# Epoch =  96   Loss = 114.836
# Epoch =  97   Loss = 78.417
# Epoch =  98   Loss = 178.100
# Epoch =  99   Loss = 72.296
# Epoch = 100   Loss = 51.256
# Epoch = 101   Loss = 45.666
# Epoch = 102   Loss = 44.563
# Epoch = 103   Loss = 73.742
# Epoch = 104   Loss = 72.790
# Epoch = 105   Loss = 52.209
# Epoch = 106   Loss = 38.496
# Epoch = 107   Loss = 70.815
# Epoch = 108   Loss = 73.860
# Epoch = 109   Loss = 51.638
# Epoch = 110   Loss = 33.199
# Epoch = 111   Loss = 49.172
# Epoch = 112   Loss = 109.297
# Epoch = 113   Loss = 33.238
# Epoch = 114   Loss = 29.413
# Epoch = 115   Loss = 59.789
# Epoch = 116   Loss = 78.269
# Epoch = 117   Loss = 44.828
# Epoch = 118   Loss = 53.143
# Epoch = 119   Loss = 64.325
# Epoch = 120   Loss = 32.785
# Epoch = 121   Loss = 31.117
# Epoch = 122   Loss = 30.795
# Epoch = 123   Loss = 30.641
# Epoch = 124   Loss = 39.608
# Epoch = 125   Loss = 77.969
# Epoch = 126   Loss = 51.136
# Epoch = 127   Loss = 37.420
# Epoch = 128   Loss = 30.084
# Epoch = 129   Loss = 29.526
# Epoch = 130   Loss = 34.201
# Epoch = 131   Loss = 29.104
# Epoch = 132   Loss = 35.904
# Epoch = 133   Loss = 27.801
# Epoch = 134   Loss = 29.626
# Epoch = 135   Loss = 42.823
# Epoch = 136   Loss = 23.809
# Epoch = 137   Loss = 28.916
# Epoch = 138   Loss = 29.507
# Epoch = 139   Loss = 26.143
# Epoch = 140   Loss = 27.150
# Epoch = 141   Loss = 24.506
# Epoch = 142   Loss = 24.106
# Epoch = 143   Loss = 23.917
# Epoch = 144   Loss = 24.531
# Epoch = 145   Loss = 21.977
# Epoch = 146   Loss = 36.755
# Epoch = 147   Loss = 23.267
# Epoch = 148   Loss = 21.073
# Epoch = 149   Loss = 41.943
# Epoch = 150   Loss = 47.831
# Epoch = 151   Loss = 35.830
# Epoch = 152   Loss = 23.322
# Epoch = 153   Loss = 39.161
# Epoch = 154   Loss = 24.073
# Epoch = 155   Loss = 30.253
# Epoch = 156   Loss = 47.682
# Epoch = 157   Loss = 39.532
# Epoch = 158   Loss = 34.952
# Epoch = 159   Loss = 21.214
# Epoch = 160   Loss = 21.054
# Epoch = 161   Loss = 20.271
# Epoch = 162   Loss = 20.105
# Epoch = 163   Loss = 21.986
# Epoch = 164   Loss = 28.174
# Epoch = 165   Loss = 62.859
# Epoch = 166   Loss = 41.927
# Epoch = 167   Loss = 27.968
# Epoch = 168   Loss = 55.093
# Epoch = 169   Loss = 36.973
# Epoch = 170   Loss = 28.385
# Epoch = 171   Loss = 42.615
# Epoch = 172   Loss = 38.956
# Epoch = 173   Loss = 26.012
# Epoch = 174   Loss = 29.845
# Epoch = 175   Loss = 20.252
# Epoch = 176   Loss = 30.605
# Epoch = 177   Loss = 45.990
# Epoch = 178   Loss = 31.495
# Epoch = 179   Loss = 24.238
# Epoch = 180   Loss = 18.453
# Epoch = 181   Loss = 30.104
# Epoch = 182   Loss = 21.153
# Epoch = 183   Loss = 21.787
# Epoch = 184   Loss = 24.964
# Epoch = 185   Loss = 34.921
# Epoch = 186   Loss = 17.533
# Epoch = 187   Loss = 24.829
# Epoch = 188   Loss = 33.389
# Epoch = 189   Loss = 29.027
# Epoch = 190   Loss = 20.132
# Epoch = 191   Loss = 19.739
# Epoch = 192   Loss = 33.183
# Epoch = 193   Loss = 25.361
# Epoch = 194   Loss = 25.277
# Epoch = 195   Loss = 64.004
# Epoch = 196   Loss = 57.428
# Epoch = 197   Loss = 32.771
# Epoch = 198   Loss = 23.708
# Epoch = 199   Loss = 23.216
# Epoch = 200   Loss = 19.188
# Epoch = 201   Loss = 27.614
# Epoch = 202   Loss = 24.046
# Epoch = 203   Loss = 20.765
# Epoch = 204   Loss = 23.013
# Epoch = 205   Loss = 20.112
# Epoch = 206   Loss = 20.888
# Epoch = 207   Loss = 17.942
# Epoch = 208   Loss = 20.093
# Epoch = 209   Loss = 26.690
# Epoch = 210   Loss = 22.911
# Epoch = 211   Loss = 22.887
# Epoch = 212   Loss = 26.270
# Epoch = 213   Loss = 21.062
# Epoch = 214   Loss = 26.498
# Epoch = 215   Loss = 21.923
# Epoch = 216   Loss = 21.144
# Epoch = 217   Loss = 18.701
# Epoch = 218   Loss = 16.018
# Epoch = 219   Loss = 14.955
# Epoch = 220   Loss = 16.621
# Epoch = 221   Loss = 17.495
# Epoch = 222   Loss = 25.632
# Epoch = 223   Loss = 20.596
# Epoch = 224   Loss = 23.872
# Epoch = 225   Loss = 19.782
# Epoch = 226   Loss = 76.656
# Epoch = 227   Loss = 26.793
# Epoch = 228   Loss = 21.502
# Epoch = 229   Loss = 19.052
# Epoch = 230   Loss = 17.689
# Epoch = 231   Loss = 20.614
# Epoch = 232   Loss = 16.735
# Epoch = 233   Loss = 17.116
# Epoch = 234   Loss = 17.106
# Epoch = 235   Loss = 18.346
# Epoch = 236   Loss = 19.899
# Epoch = 237   Loss = 19.904
# Epoch = 238   Loss = 18.442
# Epoch = 239   Loss = 19.361
# Epoch = 240   Loss = 17.044
# Epoch = 241   Loss = 17.374
# Epoch = 242   Loss = 12.427
# Epoch = 243   Loss = 11.011
# Epoch = 244   Loss = 10.717
# Epoch = 245   Loss = 10.613
# Epoch = 246   Loss = 10.572
# Epoch = 247   Loss = 10.540
# Epoch = 248   Loss = 10.513
# Epoch = 249   Loss = 10.490
# Epoch = 250   Loss = 10.472
# Epoch = 251   Loss = 10.460
# Epoch = 252   Loss = 10.453
# Epoch = 253   Loss = 10.452
# Epoch = 254   Loss = 10.461
# Epoch = 255   Loss = 10.488
# Epoch = 256   Loss = 10.549
# Epoch = 257   Loss = 10.663
# Epoch = 258   Loss = 10.829
# Epoch = 259   Loss = 10.986
# Epoch = 260   Loss = 10.970
# Epoch = 261   Loss = 10.584
# Epoch = 262   Loss = 9.695
# Epoch = 263   Loss = 14.289
# Epoch = 264   Loss = 72.535
# Epoch = 265   Loss = 32.733
# Epoch = 266   Loss = 22.187
# Epoch = 267   Loss = 10.760
# Epoch = 268   Loss = 10.752
# Epoch = 269   Loss = 10.916
# Epoch = 270   Loss = 10.989
# Epoch = 271   Loss = 10.712
# Epoch = 272   Loss = 10.349
# Epoch = 273   Loss = 10.098
# Epoch = 274   Loss = 9.760
# Epoch = 275   Loss = 15.638
# Epoch = 276   Loss = 12.525
# Epoch = 277   Loss = 10.342
# Epoch = 278   Loss = 10.552
# Epoch = 279   Loss = 14.290
# Epoch = 280   Loss = 18.644
# Epoch = 281   Loss = 68.890
# Epoch = 282   Loss = 26.819
# Epoch = 283   Loss = 63.133
# Epoch = 284   Loss = 18.291
# Epoch = 285   Loss = 12.961
# Epoch = 286   Loss = 16.029
# Epoch = 287   Loss = 16.235
# Epoch = 288   Loss = 10.124
# Epoch = 289   Loss = 8.826
# Epoch = 290   Loss = 10.759
# Epoch = 291   Loss = 11.877
# Epoch = 292   Loss = 16.639
# Epoch = 293   Loss = 81.828
# Epoch = 294   Loss = 97.201
# Epoch = 295   Loss = 30.676
# Epoch = 296   Loss = 16.988
# Epoch = 297   Loss = 15.536
# Epoch = 298   Loss = 14.894
# Epoch = 299   Loss = 12.444
# Epoch = 300   Loss = 12.264
# Epoch = 301   Loss = 11.828
# Epoch = 302   Loss = 9.477
# Epoch = 303   Loss = 8.911
# Epoch = 304   Loss = 8.625
# Epoch = 305   Loss = 8.916
# Epoch = 306   Loss = 8.684
# Epoch = 307   Loss = 7.976
# Epoch = 308   Loss = 8.092
# Epoch = 309   Loss = 8.036
# Epoch = 310   Loss = 7.872
# Epoch = 311   Loss = 7.923
# Epoch = 312   Loss = 7.771
# Epoch = 313   Loss = 7.720
# Epoch = 314   Loss = 7.584
# Epoch = 315   Loss = 7.492
# Epoch = 316   Loss = 7.418
# Epoch = 317   Loss = 7.113
# Epoch = 318   Loss = 6.966
# Epoch = 319   Loss = 6.737
# Epoch = 320   Loss = 6.936
# Epoch = 321   Loss = 6.716
# Epoch = 322   Loss = 6.753
# Epoch = 323   Loss = 6.877
# Epoch = 324   Loss = 6.701
# Epoch = 325   Loss = 6.675
# Epoch = 326   Loss = 6.673
# Epoch = 327   Loss = 6.810
# Epoch = 328   Loss = 8.109
# Epoch = 329   Loss = 9.353
# Epoch = 330   Loss = 7.538
# Epoch = 331   Loss = 33.888
# Epoch = 332   Loss = 24.787
# Epoch = 333   Loss = 10.535
# Epoch = 334   Loss = 16.969
# Epoch = 335   Loss = 20.970
# Epoch = 336   Loss = 28.691
# Epoch = 337   Loss = 25.842
# Epoch = 338   Loss = 14.400
# Epoch = 339   Loss = 15.178
# Epoch = 340   Loss = 8.147
# Epoch = 341   Loss = 7.764
# Epoch = 342   Loss = 7.272
# Epoch = 343   Loss = 8.267
# Epoch = 344   Loss = 7.607
# Epoch = 345   Loss = 6.387
# Epoch = 346   Loss = 6.570
# Epoch = 347   Loss = 8.614
# Epoch = 348   Loss = 8.039
# Epoch = 349   Loss = 8.031
# Epoch = 350   Loss = 8.028
# Epoch = 351   Loss = 7.643
# Epoch = 352   Loss = 6.138
# Epoch = 353   Loss = 9.705
# Epoch = 354   Loss = 29.152
# Epoch = 355   Loss = 31.210
# Epoch = 356   Loss = 14.602
# Epoch = 357   Loss = 12.658
# Epoch = 358   Loss = 15.157
# Epoch = 359   Loss = 10.028
# Epoch = 360   Loss = 7.875
# Epoch = 361   Loss = 6.965
# Epoch = 362   Loss = 6.260
# Epoch = 363   Loss = 7.014
# Epoch = 364   Loss = 7.757
# Epoch = 365   Loss = 7.156
# Epoch = 366   Loss = 6.251
# Epoch = 367   Loss = 5.491
# Epoch = 368   Loss = 8.021
# Epoch = 369   Loss = 7.533
# Epoch = 370   Loss = 7.172
# Epoch = 371   Loss = 5.589
# Epoch = 372   Loss = 5.184
# Epoch = 373   Loss = 8.080
# Epoch = 374   Loss = 10.171
# Epoch = 375   Loss = 14.843
# Epoch = 376   Loss = 28.883
# Epoch = 377   Loss = 19.862
# Epoch = 378   Loss = 7.976
# Epoch = 379   Loss = 6.822
# Epoch = 380   Loss = 7.246
# Epoch = 381   Loss = 5.688
# Epoch = 382   Loss = 5.332
# Epoch = 383   Loss = 5.686
# Epoch = 384   Loss = 7.197
# Epoch = 385   Loss = 4.904
# Epoch = 386   Loss = 6.188
# Epoch = 387   Loss = 5.244
# Epoch = 388   Loss = 6.800
# Epoch = 389   Loss = 5.695
# Epoch = 390   Loss = 9.461
# Epoch = 391   Loss = 5.484
# Epoch = 392   Loss = 6.546
# Epoch = 393   Loss = 30.156
# Epoch = 394   Loss = 7.241
# Epoch = 395   Loss = 5.077
# Epoch = 396   Loss = 5.122
# Epoch = 397   Loss = 5.004
# Epoch = 398   Loss = 4.794
# Epoch = 399   Loss = 4.650
# Epoch = 400   Loss = 4.614
# Epoch = 401   Loss = 4.884
# Epoch = 402   Loss = 7.073
# Epoch = 403   Loss = 10.096
# Epoch = 404   Loss = 8.691
# Epoch = 405   Loss = 17.533
# Epoch = 406   Loss = 8.352
# Epoch = 407   Loss = 5.157
# Epoch = 408   Loss = 6.691
# Epoch = 409   Loss = 8.804
# Epoch = 410   Loss = 7.317
# Epoch = 411   Loss = 17.213
# Epoch = 412   Loss = 42.166
# Epoch = 413   Loss = 17.677
# Epoch = 414   Loss = 13.475
# Epoch = 415   Loss = 6.252
# Epoch = 416   Loss = 6.598
# Epoch = 417   Loss = 6.436
# Epoch = 418   Loss = 5.170
# Epoch = 419   Loss = 4.808
# Epoch = 420   Loss = 4.943
# Epoch = 421   Loss = 5.639
# Epoch = 422   Loss = 5.823
# Epoch = 423   Loss = 4.302
# Epoch = 424   Loss = 7.052
# Epoch = 425   Loss = 14.093
# Epoch = 426   Loss = 7.366
# Epoch = 427   Loss = 5.373
# Epoch = 428   Loss = 6.402
# Epoch = 429   Loss = 4.730
# Epoch = 430   Loss = 4.351
# Epoch = 431   Loss = 6.384
# Epoch = 432   Loss = 7.304
# Epoch = 433   Loss = 10.209
# Epoch = 434   Loss = 8.534
# Epoch = 435   Loss = 8.927
# Epoch = 436   Loss = 5.504
# Epoch = 437   Loss = 7.593
# Epoch = 438   Loss = 12.334
# Epoch = 439   Loss = 6.000
# Epoch = 440   Loss = 11.995
# Epoch = 441   Loss = 28.162
# Epoch = 442   Loss = 13.902
# Epoch = 443   Loss = 5.134
# Epoch = 444   Loss = 5.007
# Epoch = 445   Loss = 5.242
# Epoch = 446   Loss = 4.958
# Epoch = 447   Loss = 4.613
# Epoch = 448   Loss = 4.330
# Epoch = 449   Loss = 4.068
# Epoch = 450   Loss = 3.759
# Epoch = 451   Loss = 4.702
# Epoch = 452   Loss = 10.308
# Epoch = 453   Loss = 15.927
# Epoch = 454   Loss = 12.618
# Epoch = 455   Loss = 16.328
# Epoch = 456   Loss = 5.312
# Epoch = 457   Loss = 9.112
# Epoch = 458   Loss = 10.340
# Epoch = 459   Loss = 6.466
# Epoch = 460   Loss = 6.246
# Epoch = 461   Loss = 8.864
# Epoch = 462   Loss = 5.057
# Epoch = 463   Loss = 5.307
# Epoch = 464   Loss = 4.742
# Epoch = 465   Loss = 4.491
# Epoch = 466   Loss = 4.268
# Epoch = 467   Loss = 3.960
# Epoch = 468   Loss = 3.615
# Epoch = 469   Loss = 5.285
# Epoch = 470   Loss = 32.265
# Epoch = 471   Loss = 19.757
# Epoch = 472   Loss = 11.716
# Epoch = 473   Loss = 11.941
# Epoch = 474   Loss = 14.392
# Epoch = 475   Loss = 10.997
# Epoch = 476   Loss = 6.575
# Epoch = 477   Loss = 6.252
# Epoch = 478   Loss = 5.975
# Epoch = 479   Loss = 6.604
# Epoch = 480   Loss = 5.543
# Epoch = 481   Loss = 5.157
# Epoch = 482   Loss = 5.197
# Epoch = 483   Loss = 6.084
# Epoch = 484   Loss = 5.987
# Epoch = 485   Loss = 4.754
# Epoch = 486   Loss = 5.982
# Epoch = 487   Loss = 7.301
# Epoch = 488   Loss = 18.348
# Epoch = 489   Loss = 9.099
# Epoch = 490   Loss = 5.226
# Epoch = 491   Loss = 4.681
# Epoch = 492   Loss = 4.268
# Epoch = 493   Loss = 4.562
# Epoch = 494   Loss = 4.761
# Epoch = 495   Loss = 4.928
# Epoch = 496   Loss = 5.252
# Epoch = 497   Loss = 5.839
# Epoch = 498   Loss = 6.343
# Epoch = 499   Loss = 5.820
# Epoch = 500   Loss = 4.433
# Epoch = 501   Loss = 7.432
# Epoch = 502   Loss = 24.544
# Epoch = 503   Loss = 37.449
# Epoch = 504   Loss = 18.026
# Epoch = 505   Loss = 6.830
# Epoch = 506   Loss = 3.961
# Epoch = 507   Loss = 5.884
# Epoch = 508   Loss = 5.366
# Epoch = 509   Loss = 5.548
# Epoch = 510   Loss = 4.921
# Epoch = 511   Loss = 5.497
# Epoch = 512   Loss = 4.708
# Epoch = 513   Loss = 5.546
# Epoch = 514   Loss = 5.030
# Epoch = 515   Loss = 5.528
# Epoch = 516   Loss = 4.627
# Epoch = 517   Loss = 5.389
# Epoch = 518   Loss = 4.300
# Epoch = 519   Loss = 5.011
# Epoch = 520   Loss = 8.309
# Epoch = 521   Loss = 33.995
# Epoch = 522   Loss = 8.783
# Epoch = 523   Loss = 3.948
# Epoch = 524   Loss = 5.521
# Epoch = 525   Loss = 6.921
# Epoch = 526   Loss = 3.320
# Epoch = 527   Loss = 3.683
# Epoch = 528   Loss = 2.906
# Epoch = 529   Loss = 4.158
# Epoch = 530   Loss = 5.244
# Epoch = 531   Loss = 5.336
# Epoch = 532   Loss = 4.456
# Epoch = 533   Loss = 6.036
# Epoch = 534   Loss = 5.950
# Epoch = 535   Loss = 3.876
# Epoch = 536   Loss = 6.022
# Epoch = 537   Loss = 5.404
# Epoch = 538   Loss = 3.061
# Epoch = 539   Loss = 4.821
# Epoch = 540   Loss = 14.067
# Epoch = 541   Loss = 19.633
# Epoch = 542   Loss = 2.740
# Epoch = 543   Loss = 4.538
# Epoch = 544   Loss = 5.371
# Epoch = 545   Loss = 4.305
# Epoch = 546   Loss = 4.360
# Epoch = 547   Loss = 4.595
# Epoch = 548   Loss = 4.687
# Epoch = 549   Loss = 3.536
# Epoch = 550   Loss = 4.705
# Epoch = 551   Loss = 8.661
# Epoch = 552   Loss = 9.226
# Epoch = 553   Loss = 5.324
# Epoch = 554   Loss = 12.678
# Epoch = 555   Loss = 14.057
# Epoch = 556   Loss = 7.435
# Epoch = 557   Loss = 4.430
# Epoch = 558   Loss = 3.333
# Epoch = 559   Loss = 3.402
# Epoch = 560   Loss = 3.710
# Epoch = 561   Loss = 3.446
# Epoch = 562   Loss = 3.980
# Epoch = 563   Loss = 3.753
# Epoch = 564   Loss = 4.180
# Epoch = 565   Loss = 4.600
# Epoch = 566   Loss = 3.989
# Epoch = 567   Loss = 3.729
# Epoch = 568   Loss = 6.107
# Epoch = 569   Loss = 7.537
# Epoch = 570   Loss = 10.039
# Epoch = 571   Loss = 5.507
# Epoch = 572   Loss = 5.772
# Epoch = 573   Loss = 3.636
# Epoch = 574   Loss = 4.289
# Epoch = 575   Loss = 15.886
# Epoch = 576   Loss = 23.091
# Epoch = 577   Loss = 2.975
# Epoch = 578   Loss = 3.345
# Epoch = 579   Loss = 3.083
# Epoch = 580   Loss = 4.465
# Epoch = 581   Loss = 4.522
# Epoch = 582   Loss = 3.924
# Epoch = 583   Loss = 4.107
# Epoch = 584   Loss = 4.226
# Epoch = 585   Loss = 4.062
# Epoch = 586   Loss = 3.757
# Epoch = 587   Loss = 3.547
# Epoch = 588   Loss = 3.522
# Epoch = 589   Loss = 3.670
# Epoch = 590   Loss = 4.388
# Epoch = 591   Loss = 6.139
# Epoch = 592   Loss = 18.246
# Epoch = 593   Loss = 35.510
# Epoch = 594   Loss = 18.084
# Epoch = 595   Loss = 2.567
# Epoch = 596   Loss = 4.034
# Epoch = 597   Loss = 3.603
# Epoch = 598   Loss = 3.961
# Epoch = 599   Loss = 3.708
# Epoch = 600   Loss = 3.673
# Epoch = 601   Loss = 3.517
# Epoch = 602   Loss = 3.460
# Epoch = 603   Loss = 3.530
# Epoch = 604   Loss = 3.533
# Epoch = 605   Loss = 3.588
# Epoch = 606   Loss = 3.519
# Epoch = 607   Loss = 3.400
# Epoch = 608   Loss = 3.294
# Epoch = 609   Loss = 3.217
# Epoch = 610   Loss = 3.364
# Epoch = 611   Loss = 4.217
# Epoch = 612   Loss = 3.763
# Epoch = 613   Loss = 6.024
# Epoch = 614   Loss = 24.322
# Epoch = 615   Loss = 44.740
# Epoch = 616   Loss = 15.184
# Epoch = 617   Loss = 11.837
# Epoch = 618   Loss = 5.888
# Epoch = 619   Loss = 7.279
# Epoch = 620   Loss = 5.057
# Epoch = 621   Loss = 6.450
# Epoch = 622   Loss = 7.195
# Epoch = 623   Loss = 5.480
# Epoch = 624   Loss = 4.615
# Epoch = 625   Loss = 3.613
# Epoch = 626   Loss = 6.085
# Epoch = 627   Loss = 15.397
# Epoch = 628   Loss = 10.648
# Epoch = 629   Loss = 4.133
# Epoch = 630   Loss = 4.092
# Epoch = 631   Loss = 4.345
# Epoch = 632   Loss = 5.284
# Epoch = 633   Loss = 7.489
# Epoch = 634   Loss = 6.499
# Epoch = 635   Loss = 4.077
# Epoch = 636   Loss = 3.428
# Epoch = 637   Loss = 4.985
# Epoch = 638   Loss = 8.583
# Epoch = 639   Loss = 7.634
# Epoch = 640   Loss = 3.864
# Epoch = 641   Loss = 3.676
# Epoch = 642   Loss = 4.573
# Epoch = 643   Loss = 5.557
# Epoch = 644   Loss = 5.040
# Epoch = 645   Loss = 4.669
# Epoch = 646   Loss = 4.650
# Epoch = 647   Loss = 5.695
# Epoch = 648   Loss = 5.847
# Epoch = 649   Loss = 3.524
# Epoch = 650   Loss = 3.707
# Epoch = 651   Loss = 3.421
# Epoch = 652   Loss = 3.377
# Epoch = 653   Loss = 3.375
# Epoch = 654   Loss = 3.307
# Epoch = 655   Loss = 3.291
# Epoch = 656   Loss = 3.417
# Epoch = 657   Loss = 3.256
# Epoch = 658   Loss = 5.823
# Epoch = 659   Loss = 14.036
# Epoch = 660   Loss = 29.545
# Epoch = 661   Loss = 7.037
# Epoch = 662   Loss = 3.114
# Epoch = 663   Loss = 3.568
# Epoch = 664   Loss = 2.944
# Epoch = 665   Loss = 3.542
# Epoch = 666   Loss = 3.126
# Epoch = 667   Loss = 3.390
# Epoch = 668   Loss = 3.040
# Epoch = 669   Loss = 3.219
# Epoch = 670   Loss = 2.989
# Epoch = 671   Loss = 3.004
# Epoch = 672   Loss = 2.907
# Epoch = 673   Loss = 2.852
# Epoch = 674   Loss = 2.988
# Epoch = 675   Loss = 3.001
# Epoch = 676   Loss = 2.873
# Epoch = 677   Loss = 4.273
# Epoch = 678   Loss = 10.793
# Epoch = 679   Loss = 3.558
# Epoch = 680   Loss = 5.562
# Epoch = 681   Loss = 5.929
# Epoch = 682   Loss = 3.994
# Epoch = 683   Loss = 4.874
# Epoch = 684   Loss = 5.535
# Epoch = 685   Loss = 4.140
# Epoch = 686   Loss = 3.169
# Epoch = 687   Loss = 3.280
# Epoch = 688   Loss = 4.656
# Epoch = 689   Loss = 6.535
# Epoch = 690   Loss = 4.000
# Epoch = 691   Loss = 2.934
# Epoch = 692   Loss = 4.098
# Epoch = 693   Loss = 6.460
# Epoch = 694   Loss = 4.835
# Epoch = 695   Loss = 3.513
# Epoch = 696   Loss = 3.753
# Epoch = 697   Loss = 3.264
# Epoch = 698   Loss = 2.984
# Epoch = 699   Loss = 3.814
# Epoch = 700   Loss = 5.556
# Epoch = 701   Loss = 7.300
# Epoch = 702   Loss = 3.025
# Epoch = 703   Loss = 4.015
# Epoch = 704   Loss = 4.468
# Epoch = 705   Loss = 3.660
# Epoch = 706   Loss = 2.912
# Epoch = 707   Loss = 5.876
# Epoch = 708   Loss = 7.449
# Epoch = 709   Loss = 2.556
# Epoch = 710   Loss = 2.725
# Epoch = 711   Loss = 2.834
# Epoch = 712   Loss = 2.632
# Epoch = 713   Loss = 3.170
# Epoch = 714   Loss = 3.134
# Epoch = 715   Loss = 3.277
# Epoch = 716   Loss = 6.528
# Epoch = 717   Loss = 14.539
# Epoch = 718   Loss = 34.238
# Epoch = 719   Loss = 9.850
# Epoch = 720   Loss = 3.617
# Epoch = 721   Loss = 2.927
# Epoch = 722   Loss = 2.800
# Epoch = 723   Loss = 2.742
# Epoch = 724   Loss = 2.701
# Epoch = 725   Loss = 2.714
# Epoch = 726   Loss = 2.733
# Epoch = 727   Loss = 2.773
# Epoch = 728   Loss = 2.868
# Epoch = 729   Loss = 2.987
# Epoch = 730   Loss = 3.027
# Epoch = 731   Loss = 2.960
# Epoch = 732   Loss = 2.886
# Epoch = 733   Loss = 2.919
# Epoch = 734   Loss = 3.211
# Epoch = 735   Loss = 3.376
# Epoch = 736   Loss = 3.135
# Epoch = 737   Loss = 3.909
# Epoch = 738   Loss = 14.291
# Epoch = 739   Loss = 23.097
# Epoch = 740   Loss = 7.977
# Epoch = 741   Loss = 2.564
# Epoch = 742   Loss = 3.069
# Epoch = 743   Loss = 2.456
# Epoch = 744   Loss = 2.521
# Epoch = 745   Loss = 2.535
# Epoch = 746   Loss = 2.480
# Epoch = 747   Loss = 2.459
# Epoch = 748   Loss = 2.457
# Epoch = 749   Loss = 2.492
# Epoch = 750   Loss = 3.504
# Epoch = 751   Loss = 10.401
# Epoch = 752   Loss = 23.504
# Epoch = 753   Loss = 6.095
# Epoch = 754   Loss = 2.440
# Epoch = 755   Loss = 2.664
# Epoch = 756   Loss = 2.443
# Epoch = 757   Loss = 2.429
# Epoch = 758   Loss = 2.409
# Epoch = 759   Loss = 2.365
# Epoch = 760   Loss = 2.344
# Epoch = 761   Loss = 2.350
# Epoch = 762   Loss = 2.507
# Epoch = 763   Loss = 2.974
# Epoch = 764   Loss = 2.837
# Epoch = 765   Loss = 2.525
# Epoch = 766   Loss = 4.546
# Epoch = 767   Loss = 15.322
# Epoch = 768   Loss = 19.724
# Epoch = 769   Loss = 7.635
# Epoch = 770   Loss = 2.206
# Epoch = 771   Loss = 2.425
# Epoch = 772   Loss = 2.321
# Epoch = 773   Loss = 2.236
# Epoch = 774   Loss = 2.224
# Epoch = 775   Loss = 2.221
# Epoch = 776   Loss = 2.207
# Epoch = 777   Loss = 2.198
# Epoch = 778   Loss = 2.390
# Epoch = 779   Loss = 2.903
# Epoch = 780   Loss = 2.554
# Epoch = 781   Loss = 2.555
# Epoch = 782   Loss = 2.302
# Epoch = 783   Loss = 2.227
# Epoch = 784   Loss = 4.136
# Epoch = 785   Loss = 13.859
# Epoch = 786   Loss = 3.230
# Epoch = 787   Loss = 5.133
# Epoch = 788   Loss = 3.716
# Epoch = 789   Loss = 2.434
# Epoch = 790   Loss = 2.183
# Epoch = 791   Loss = 2.748
# Epoch = 792   Loss = 2.502
# Epoch = 793   Loss = 4.059
# Epoch = 794   Loss = 6.492
# Epoch = 795   Loss = 2.051
# Epoch = 796   Loss = 2.536
# Epoch = 797   Loss = 2.008
# Epoch = 798   Loss = 2.079
# Epoch = 799   Loss = 2.670
# Epoch = 800   Loss = 5.862
# Epoch = 801   Loss = 9.879
# Epoch = 802   Loss = 13.626
# Epoch = 803   Loss = 7.620
# Epoch = 804   Loss = 2.675
# Epoch = 805   Loss = 1.911
# Epoch = 806   Loss = 1.872
# Epoch = 807   Loss = 1.932
# Epoch = 808   Loss = 2.139
# Epoch = 809   Loss = 2.385
# Epoch = 810   Loss = 2.417
# Epoch = 811   Loss = 2.249
# Epoch = 812   Loss = 2.098
# Epoch = 813   Loss = 1.988
# Epoch = 814   Loss = 1.875
# Epoch = 815   Loss = 2.070
# Epoch = 816   Loss = 5.822
# Epoch = 817   Loss = 14.140
# Epoch = 818   Loss = 6.645
# Epoch = 819   Loss = 5.484
# Epoch = 820   Loss = 2.015
# Epoch = 821   Loss = 1.828
# Epoch = 822   Loss = 1.818
# Epoch = 823   Loss = 1.947
# Epoch = 824   Loss = 2.263
# Epoch = 825   Loss = 2.533
# Epoch = 826   Loss = 2.407
# Epoch = 827   Loss = 2.178
# Epoch = 828   Loss = 2.099
# Epoch = 829   Loss = 2.272
# Epoch = 830   Loss = 2.715
# Epoch = 831   Loss = 2.564
# Epoch = 832   Loss = 1.977
# Epoch = 833   Loss = 1.937
# Epoch = 834   Loss = 5.985
# Epoch = 835   Loss = 15.663
# Epoch = 836   Loss = 8.277
# Epoch = 837   Loss = 6.452
# Epoch = 838   Loss = 1.941
# Epoch = 839   Loss = 1.641
# Epoch = 840   Loss = 1.585
# Epoch = 841   Loss = 1.567
# Epoch = 842   Loss = 1.593
# Epoch = 843   Loss = 1.811
# Epoch = 844   Loss = 2.563
# Epoch = 845   Loss = 2.760
# Epoch = 846   Loss = 2.042
# Epoch = 847   Loss = 1.713
# Epoch = 848   Loss = 1.590
# Epoch = 849   Loss = 4.147
# Epoch = 850   Loss = 16.462
# Epoch = 851   Loss = 2.803
# Epoch = 852   Loss = 4.604
# Epoch = 853   Loss = 5.110
# Epoch = 854   Loss = 4.160
# Epoch = 855   Loss = 2.662
# Epoch = 856   Loss = 1.795
# Epoch = 857   Loss = 2.935
# Epoch = 858   Loss = 2.140
# Epoch = 859   Loss = 2.887
# Epoch = 860   Loss = 4.268
# Epoch = 861   Loss = 5.085
# Epoch = 862   Loss = 3.881
# Epoch = 863   Loss = 2.289
# Epoch = 864   Loss = 2.376
# Epoch = 865   Loss = 2.181
# Epoch = 866   Loss = 1.725
# Epoch = 867   Loss = 2.084
# Epoch = 868   Loss = 2.455
# Epoch = 869   Loss = 2.642
# Epoch = 870   Loss = 2.758
# Epoch = 871   Loss = 2.517
# Epoch = 872   Loss = 2.172
# Epoch = 873   Loss = 2.105
# Epoch = 874   Loss = 2.523
# Epoch = 875   Loss = 3.025
# Epoch = 876   Loss = 2.180
# Epoch = 877   Loss = 1.680
# Epoch = 878   Loss = 1.631
# Epoch = 879   Loss = 5.918
# Epoch = 880   Loss = 21.350
# Epoch = 881   Loss = 3.090
# Epoch = 882   Loss = 3.108
# Epoch = 883   Loss = 3.937
# Epoch = 884   Loss = 3.910
# Epoch = 885   Loss = 3.089
# Epoch = 886   Loss = 1.894
# Epoch = 887   Loss = 2.189
# Epoch = 888   Loss = 1.904
# Epoch = 889   Loss = 1.815
# Epoch = 890   Loss = 2.062
# Epoch = 891   Loss = 2.462
# Epoch = 892   Loss = 2.751
# Epoch = 893   Loss = 2.536
# Epoch = 894   Loss = 2.046
# Epoch = 895   Loss = 1.824
# Epoch = 896   Loss = 2.050
# Epoch = 897   Loss = 3.137
# Epoch = 898   Loss = 2.621
# Epoch = 899   Loss = 1.736
# Epoch = 900   Loss = 1.534
# Epoch = 901   Loss = 4.904
# Epoch = 902   Loss = 24.263
# Epoch = 903   Loss = 2.281
# Epoch = 904   Loss = 2.002
# Epoch = 905   Loss = 3.026
# Epoch = 906   Loss = 4.661
# Epoch = 907   Loss = 4.638
# Epoch = 908   Loss = 3.369
# Epoch = 909   Loss = 1.850
# Epoch = 910   Loss = 2.625
# Epoch = 911   Loss = 1.472
# Epoch = 912   Loss = 1.792
# Epoch = 913   Loss = 2.082
# Epoch = 914   Loss = 2.064
# Epoch = 915   Loss = 2.402
# Epoch = 916   Loss = 2.659
# Epoch = 917   Loss = 2.298
# Epoch = 918   Loss = 1.866
# Epoch = 919   Loss = 1.769
# Epoch = 920   Loss = 2.180
# Epoch = 921   Loss = 3.266
# Epoch = 922   Loss = 2.068
# Epoch = 923   Loss = 1.569
# Epoch = 924   Loss = 1.532
# Epoch = 925   Loss = 5.949
# Epoch = 926   Loss = 24.509
# Epoch = 927   Loss = 2.909
# Epoch = 928   Loss = 2.591
# Epoch = 929   Loss = 3.341
# Epoch = 930   Loss = 3.494
# Epoch = 931   Loss = 3.026
# Epoch = 932   Loss = 1.997
# Epoch = 933   Loss = 1.658
# Epoch = 934   Loss = 2.720
# Epoch = 935   Loss = 1.690
# Epoch = 936   Loss = 2.175
# Epoch = 937   Loss = 3.986
# Epoch = 938   Loss = 6.897
# Epoch = 939   Loss = 1.754
# Epoch = 940   Loss = 2.707
# Epoch = 941   Loss = 1.477
# Epoch = 942   Loss = 1.584
# Epoch = 943   Loss = 2.288
# Epoch = 944   Loss = 2.164
# Epoch = 945   Loss = 2.572
# Epoch = 946   Loss = 2.605
# Epoch = 947   Loss = 2.069
# Epoch = 948   Loss = 1.790
# Epoch = 949   Loss = 1.950
# Epoch = 950   Loss = 2.708
# Epoch = 951   Loss = 2.712
# Epoch = 952   Loss = 1.940
# Epoch = 953   Loss = 1.724
# Epoch = 954   Loss = 1.893
# Epoch = 955   Loss = 3.113
# Epoch = 956   Loss = 2.915
# Epoch = 957   Loss = 2.071
# Epoch = 958   Loss = 1.885
# Epoch = 959   Loss = 2.072
# Epoch = 960   Loss = 3.342
# Epoch = 961   Loss = 2.958
# Epoch = 962   Loss = 2.265
# Epoch = 963   Loss = 2.041
# Epoch = 964   Loss = 2.148
# Epoch = 965   Loss = 3.146
# Epoch = 966   Loss = 3.486
# Epoch = 967   Loss = 2.336
# Epoch = 968   Loss = 1.821
# Epoch = 969   Loss = 1.856
# Epoch = 970   Loss = 8.258
# Epoch = 971   Loss = 19.956
# Epoch = 972   Loss = 3.636
# Epoch = 973   Loss = 4.224
# Epoch = 974   Loss = 5.524
# Epoch = 975   Loss = 4.552
# Epoch = 976   Loss = 2.598
# Epoch = 977   Loss = 1.538
# Epoch = 978   Loss = 2.121
# Epoch = 979   Loss = 1.370
# Epoch = 980   Loss = 1.542
# Epoch = 981   Loss = 1.825
# Epoch = 982   Loss = 1.775
# Epoch = 983   Loss = 1.919
# Epoch = 984   Loss = 2.096
# Epoch = 985   Loss = 2.154
# Epoch = 986   Loss = 2.106
# Epoch = 987   Loss = 2.016
# Epoch = 988   Loss = 1.963
# Epoch = 989   Loss = 1.988
# Epoch = 990   Loss = 2.075
# Epoch = 991   Loss = 2.127
# Epoch = 992   Loss = 2.049
# Epoch = 993   Loss = 1.893
# Epoch = 994   Loss = 1.757
# Epoch = 995   Loss = 1.693
# Epoch = 996   Loss = 1.781
# Epoch = 997   Loss = 2.358
# Epoch = 998   Loss = 3.236
# Epoch = 999   Loss = 1.816
#
# Done.

# %%
plt.plot(epoch_loss, linewidth=2)
plt.xlabel("Epoch", fontsize=15)
plt.ylabel("Loss", fontsize=15)
plt.show()

# %% [markdown]
# ## Prediction

# %%
y_pred = MyNeuralNet.forward(testX)

# %%
plt.figure(figsize=(15,8))
plt.plot(testY.squeeze(), linewidth=2 , label="True")
plt.plot(y_pred.squeeze(), linestyle="--",  label="Predicted")
plt.legend()
plt.show()

# %%
import os 
cwd = os.getcwd()
os.chdir(cwd)

# !jupyter nbconvert Q5_StarterCode_NumpyNeuralNet_Regression.ipynb
# Out:
# [NbConvertApp] Converting notebook Q5_StarterCode_NumpyNeuralNet_Regression.ipynb to html
# [NbConvertApp] Writing 986356 bytes to Q5_StarterCode_NumpyNeuralNet_Regression.html
