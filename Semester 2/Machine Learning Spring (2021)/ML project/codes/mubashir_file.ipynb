# %%
import pandas as pd1
import numpy as np

# %%
# cd /content/drive/MyDrive/MSDS-20/semester 2/Machine Learning Spring (2021)/ML project/codes

# %%
# !git clone https://github.com/graphdml-uiuc-jlu/geom-gcn.git
# Out:
# Cloning into 'geom-gcn'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 195 (delta 2), reused 2 (delta 0), pack-reused 189
# Receiving objects: 100% (195/195), 19.97 MiB | 15.00 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
cd geom-gcn/
# Out:
# /content/geom-gcn/geom-gcn/geom-gcn/geom-gcn/geom-gcn/geom-gcn/geom-gcn

# %%
# !pip install dgl==0.3

# %%
pip install tensorboardX

# %%
# !pip install torch

# %%
import timeit
start = timeit.default_timer()

# %% [markdown]
# [train_GCN.py](https://drive.google.com/drive/folders/1kDWk7PijzWE2ExI2rVj1eItspC-ghVbK)

# %%
# /content/drive/MyDrive/ML project/codes/geom-gcn/data/ind.citeseer.allx

# %%
# Your statements here
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Time:  0.01975573999879998

# %%
# import timeit
# start = timeit.default_timer()

# %%
# !bash NewTableThreeGAT_runs.txt

# %%
# #Your statements here
# stop = timeit.default_timer()
# print('Time: ', stop - start)

# %%
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 0 --dataset_split splits/cora_split_0.6_0.2_0.npz
# Out:
# Epoch 00000 | Train Loss 1.9465 | Train Acc 0.1384 | Val Loss 1.9217 | Val Acc 0.3178 | Time(s) 0.0394
# Epoch 00001 | Train Loss 1.9211 | Train Acc 0.3624 | Val Loss 1.8833 | Val Acc 0.3266 | Time(s) 0.0381
# Epoch 00002 | Train Loss 1.8809 | Train Acc 0.3490 | Val Loss 1.8363 | Val Acc 0.3329 | Time(s) 0.0366
# Epoch 00003 | Train Loss 1.8309 | Train Acc 0.3725 | Val Loss 1.7807 | Val Acc 0.3417 | Time(s) 0.0360
# Epoch 00004 | Train Loss 1.7772 | Train Acc 0.3742 | Val Loss 1.7173 | Val Acc 0.3631 | Time(s) 0.0361
# Epoch 00005 | Train Loss 1.7134 | Train Acc 0.3624 | Val Loss 1.6466 | Val Acc 0.3920 | Time(s) 0.0355
# Epoch 00006 | Train Loss 1.6445 | Train Acc 0.4228 | Val Loss 1.5709 | Val Acc 0.4347 | Time(s) 0.0351
# Epoch 00007 | Train Loss 1.5609 | Train Acc 0.4505 | Val Loss 1.4920 | Val Acc 0.4636 | Time(s) 0.0353
# Epoch 00008 | Train Loss 1.4949 | Train Acc 0.4480 | Val Loss 1.4110 | Val Acc 0.5138 | Time(s) 0.0351
# ...

# %%
# a=!python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 0 --dataset_split splits/cora_split_0.6_0.2_0.npz
# for i in a:
#   d=i.split("|")
    


# df = pd.DataFrame(a,columns=["ID"])
# df.describe()

# %%
# print(d)
# df = pd1.DataFrame(d,columns=["ID"])
# df

# %%
df0=pd1.read_csv("/content/geom-gcn/bestacc.csv")
df0.describe()
# Out:
#        3.718592822551727295e-01
# count                147.000000
# mean                   0.834248
# std                    0.102434
# min                    0.373116
# 25%                    0.860553
# 50%                    0.865578
# 75%                    0.870603
# max                    0.884422

# %%
df1=pd1.read_csv("/content/geom-gcn/bestacc.csv")
df1.describe()
# Out:
#        3.718592822551727295e-01
# count                147.000000
# mean                   0.834248
# std                    0.102434
# min                    0.373116
# 25%                    0.860553
# 50%                    0.865578
# 75%                    0.870603
# max                    0.884422

# %%
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 2 --dataset_split splits/cora_split_0.6_0.2_0.npz
# Out:
# Epoch 00000 | Train Loss 1.9464 | Train Acc 0.1275 | Val Loss 1.9229 | Val Acc 0.3869 | Time(s) 0.0362
# Epoch 00001 | Train Loss 1.9214 | Train Acc 0.3826 | Val Loss 1.8814 | Val Acc 0.4585 | Time(s) 0.0343
# Epoch 00002 | Train Loss 1.8786 | Train Acc 0.4581 | Val Loss 1.8299 | Val Acc 0.4887 | Time(s) 0.0336
# Epoch 00003 | Train Loss 1.8268 | Train Acc 0.4874 | Val Loss 1.7722 | Val Acc 0.5126 | Time(s) 0.0331
# Epoch 00004 | Train Loss 1.7597 | Train Acc 0.5059 | Val Loss 1.7088 | Val Acc 0.5276 | Time(s) 0.0331
# Epoch 00005 | Train Loss 1.6931 | Train Acc 0.5436 | Val Loss 1.6399 | Val Acc 0.5440 | Time(s) 0.0329
# Epoch 00006 | Train Loss 1.6372 | Train Acc 0.5369 | Val Loss 1.5663 | Val Acc 0.5528 | Time(s) 0.0328
# Epoch 00007 | Train Loss 1.5504 | Train Acc 0.5411 | Val Loss 1.4892 | Val Acc 0.5628 | Time(s) 0.0331
# Epoch 00008 | Train Loss 1.4693 | Train Acc 0.5545 | Val Loss 1.4112 | Val Acc 0.5804 | Time(s) 0.0329
# ...

# %%
ls
# Out:
# data/                               runs/
# embedding_method_combinations_all/  splits/
# ExperimentTwoAllGeomGCN_runs.txt    structural_neighborhood/
# ExperimentTwoAll_results.csv        train_GAT.py
# ExperimentTwoPairs_results.csv      train_GCN.py
# new_data/                           train_GeomGCN_ExperimentTwoAll.py
# NewTableThreeGAT_runs.txt           train_GeomGCN.py
# NewTableThreeGCN_runs.txt           unconnected_nodes/
# NewTableThreeGeomGCN_runs.txt       utils_data.py
# preview.PNG                         utils_layers.py
# __pycache__/                        utils.py
# README.md

# %%
# !python train_GCN.py --dataset citeseer --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 12 --dataset_split splits/citeseer_split_0.6_0.2_2.npz
# Out:
# /content/geom-gcn/geom-gcn/geom-gcn/geom-gcn/geom-gcn/geom-gcn/geom-gcn/utils.py:118: RuntimeWarning: divide by zero encountered in power
#   r_inv = np.power(rowsum, -1).flatten()
# Epoch 00000 | Train Loss 1.7918 | Train Acc 0.1516 | Val Loss 1.7705 | Val Acc 0.5925 | Time(s) 0.0391
# Epoch 00001 | Train Loss 1.7684 | Train Acc 0.5777 | Val Loss 1.7268 | Val Acc 0.5089 | Time(s) 0.0350
# Epoch 00002 | Train Loss 1.7200 | Train Acc 0.5388 | Val Loss 1.6766 | Val Acc 0.4845 | Time(s) 0.0341
# Epoch 00003 | Train Loss 1.6659 | Train Acc 0.5251 | Val Loss 1.6208 | Val Acc 0.4977 | Time(s) 0.0368
# Epoch 00004 | Train Loss 1.6064 | Train Acc 0.5207 | Val Loss 1.5604 | Val Acc 0.5324 | Time(s) 0.0363
# Epoch 00005 | Train Loss 1.5433 | Train Acc 0.5357 | Val Loss 1.4953 | Val Acc 0.5756 | Time(s) 0.0365
# Epoch 00006 | Train Loss 1.4679 | Train Acc 0.5808 | Val Loss 1.4271 | Val Acc 0.6357 | Time(s) 0.0367
# ...

# %%
# !python train_GCN.py --dataset cora --num_hidden 16 --num_heads_layer_one 1 --num_heads_layer_two 1 --weight_decay_layer_one 5e-06 --weight_decay_layer_two 5e-06 --learning_rate 0.05 --dropout_rate 0.5 --run_id 1 --dataset_split splits/cora_split_0.6_0.2_0.npz
# Out:
# Epoch 00000 | Train Loss 1.9466 | Train Acc 0.0898 | Val Loss 1.9266 | Val Acc 0.4309 | Time(s) 0.0384
# Epoch 00001 | Train Loss 1.9262 | Train Acc 0.4329 | Val Loss 1.8906 | Val Acc 0.4196 | Time(s) 0.0370
# Epoch 00002 | Train Loss 1.8907 | Train Acc 0.4077 | Val Loss 1.8427 | Val Acc 0.4410 | Time(s) 0.0387
# Epoch 00003 | Train Loss 1.8447 | Train Acc 0.4522 | Val Loss 1.7852 | Val Acc 0.4611 | Time(s) 0.0375
# Epoch 00004 | Train Loss 1.7871 | Train Acc 0.4698 | Val Loss 1.7233 | Val Acc 0.4862 | Time(s) 0.0371
# Epoch 00005 | Train Loss 1.7222 | Train Acc 0.4924 | Val Loss 1.6579 | Val Acc 0.5013 | Time(s) 0.0366
# Epoch 00006 | Train Loss 1.6523 | Train Acc 0.4966 | Val Loss 1.5899 | Val Acc 0.5025 | Time(s) 0.0363
# Epoch 00007 | Train Loss 1.5849 | Train Acc 0.5109 | Val Loss 1.5206 | Val Acc 0.5289 | Time(s) 0.0369
# Epoch 00008 | Train Loss 1.5235 | Train Acc 0.5092 | Val Loss 1.4499 | Val Acc 0.5628 | Time(s) 0.0367
# ...
