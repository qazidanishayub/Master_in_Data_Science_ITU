# %%
cd /content/drive/MyDrive/qazi MSDS-20/semester 3/Medical Image Computing/MIC Project
# Out:
# /content/drive/MyDrive/qazi MSDS-20/semester 3/Medical Image Computing/MIC Project

# %%
# !git clone https://github.com/basiralab/SM-netFusion-PY.git
# Out:
# Cloning into 'SM-netFusion-PY'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 126 (delta 43), reused 90 (delta 22), pack-reused 0
# Receiving objects: 100% (126/126), 20.94 MiB | 13.59 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Checking out files: 100% (64/64), done.

# %%
ls
# Out:
# 'minutes of meeting.gdoc'
#  Papers.pdf
#  SM-netFusion-PY/
# 'Supervised Multi-topology Network Cross-diffusion for Population-driven Brain  Network Atlas Estimation.pdf'
# 'Supervised Multi-topology Network.ipynb'

# %%
cd SM-netFusion-PY/
# Out:
# /content/drive/My Drive/qazi MSDS-20/semester 3/Medical Image Computing/MIC Project/SM-netFusion-PY

# %%
ls
# Out:
# 0.13.2        __pycache__/                SIMLR_PY/             SNF_all.py
# graphs.png    README.md                   simulateData.py       test.ann
# Outputs.png   scoreAcrossAllCVRuns.py     SM_netFusion_demo.py  Untitled.ipynb
# Pipeline.png  ScoreFeaturesAcrossRuns.py  SM_netFusion.py

# %%
# !python SNF_all.py

# %%
# !python simulateData.py

# %%
# !python SM_netFusion.py
# Out:
# Traceback (most recent call last):
#   File "SM_netFusion.py", line 55, in <module>
#     import SIMLR_PY.SIMLR as SIMLR
#   File "/content/drive/MyDrive/qazi MSDS-20/semester 3/Medical Image Computing/MIC Project/SM-netFusion-PY/SIMLR_PY/SIMLR/__init__.py", line 1, in <module>
#     from .core import SIMLR_LARGE
#   File "/content/drive/MyDrive/qazi MSDS-20/semester 3/Medical Image Computing/MIC Project/SM-netFusion-PY/SIMLR_PY/SIMLR/core.py", line 41, in <module>
#     from . import helper
#   File "/content/drive/MyDrive/qazi MSDS-20/semester 3/Medical Image Computing/MIC Project/SM-netFusion-PY/SIMLR_PY/SIMLR/helper.py", line 9, in <module>
#     from fbpca import pca
# ModuleNotFoundError: No module named 'fbpca'
